# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
ds=pd.read_csv("E:/Datatrained/Evaluation/avacado.csv")
ds
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 0              0  27-12-2015          1.33      64236.62     1036.74
# 1              1  20-12-2015          1.35      54876.98      674.28
# 2              2  13-12-2015          0.93     118220.22      794.70
# 3              3  06-12-2015          1.08      78992.15     1132.00
# 4              4  29-11-2015          1.28      51039.60      941.48
# 5              5  22-11-2015          1.26      55979.78     1184.27
# 6              6  15-11-2015          0.99      83453.76     1368.92
# 7              7  08-11-2015          0.98     109428.33      703.75
# 8              8  01-11-2015          1.02      99811.42     1022.15
# 9              9  25-10-2015          1.07      74338.76      842.40
# 10            10  18-10-2015          1.12      84843.44      924.86
# 11            11  11-10-2015          1.28      64489.17     1582.03
# 12            12  04-10-2015          1.31      61007.10     2268.32
# 13            13  27-09-2015          0.99     106803.39     1204.88
# 14            14  20-09-2015          1.33      69759.01     1028.03
# 15            15  13-09-2015          1.28      76111.27      985.73
# 16            16  06-09-2015          1.11      99172.96      879.45
# 17            17  30-08-2015          1.07     105693.84      689.01
# 18            18  23-08-2015          1.34      79992.09      733.16
# 19            19  16-08-2015          1.33      80043.78      539.65
# 20            20  09-08-2015          1.12     111140.93      584.63
# 21            21  02-08-2015          1.45      75133.10      509.94
# 22            22  26-07-2015          1.11     106757.10      648.75
# 23            23  19-07-2015          1.26      96617.00     1042.10
# 24            24  12-07-2015          1.05     124055.31      672.25
# 25            25  05-07-2015          1.35     109252.12      869.45
# 26            26  28-06-2015          1.37      89534.81      664.23
# 27            27  21-06-2015          1.27     104849.39      804.01
# 28            28  14-06-2015          1.32      89631.30      850.58
# 29            29  07-06-2015          1.07     122743.06      656.71
# ...          ...         ...           ...           ...         ...
# 1487          37  10-04-2016          0.94    6509000.56  2248561.59
# 1488          38  03-04-2016          0.93    6060843.76  1805555.95
# 1489          39  27-03-2016          0.93    6603707.93  1935666.12
# 1490          40  20-03-2016          0.91    6476206.54  1893617.80
# 1491          41  13-03-2016          0.96    6017563.88  1750943.52
# 1492          42  06-03-2016          0.92    6429870.23  1893787.20
# 1493          43  28-02-2016          0.89    6588277.70  1873878.11
# 1494          44  21-02-2016          0.89    6374019.03  1776499.00
# 1495          45  14-02-2016          0.82    6807283.15  1998149.71
# 1496          46  07-02-2016          0.70   10361698.17  2930343.28
# 1497          47  31-01-2016          0.88    6506673.96  2126066.85
# 1498          48  24-01-2016          0.88    6246380.73  1230068.19
# 1499          49  17-01-2016          0.90    6000013.23  1653347.69
# 1500          50  10-01-2016          0.87    6303406.82  1736168.01
# 1501          51  03-01-2016          0.73    7730431.28  2315175.35
# 1502           0  25-12-2016          1.25     155793.03    36125.58
# 1503           1  18-12-2016          1.24     144634.01    35761.88
# 1504           2  11-12-2016          1.33     145815.04    43744.87
# 1505           3  04-12-2016          1.34     154742.81    39221.82
# 1506           4  27-11-2016          1.54     131453.85    38976.01
# 1507           5  20-11-2016          1.57     135608.11    44044.69
# 1508           6  13-11-2016          1.64     144089.12    49399.39
# 1509           7  06-11-2016          1.57     142095.92    36840.74
# 1510           8  30-10-2016          1.58     142955.49    39376.44
# 1511           9  23-10-2016          1.52     167741.27    54981.90
# 1512          10  16-10-2016          1.39     190846.01    57529.11
# 1513          11  09-10-2016          1.51     178235.75    43325.87
# 1514          12  02-10-2016          1.48     178410.82    46364.75
# 1515          13  25-09-2016          1.47     189131.52    54110.79
# 1516          14  18-09-2016          1.43     182978.30    43116.41
#
#             4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 0       54454.85      48.16     8696.87     8603.62       93.25         0.00
# 1       44638.81      58.33     9505.56     9408.07       97.49         0.00
# 2      109149.67     130.50     8145.35     8042.21      103.14         0.00
# 3       71976.41      72.58     5811.16     5677.40      133.76         0.00
# 4       43838.39      75.78     6183.95     5986.26      197.69         0.00
# 5       48067.99      43.61     6683.91     6556.47      127.44         0.00
# 6       73672.72      93.26     8318.86     8196.81      122.05         0.00
# 7      101815.36      80.00     6829.22     6266.85      562.37         0.00
# 8       87315.57      85.34    11388.36    11104.53      283.83         0.00
# 9       64757.44     113.00     8625.92     8061.47      564.45         0.00
# 10      75595.85     117.07     8205.66     7877.86      327.80         0.00
# 11      52677.92     105.32    10123.90     9866.27      257.63         0.00
# 12      49880.67     101.36     8756.75     8379.98      376.77         0.00
# 13      99409.21     154.84     6034.46     5888.87      145.59         0.00
# 14      59313.12     150.50     9267.36     8489.10      778.26         0.00
# 15      65696.86     142.00     9286.68     8665.19      621.49         0.00
# 16      90062.62     240.79     7990.10     7762.87      227.23         0.00
# 17      94362.67     335.43    10306.73    10218.93       87.80         0.00
# 18      67933.79     444.78    10880.36    10745.79      134.57         0.00
# 19      68666.01     394.90    10443.22    10297.68      145.54         0.00
# 20     100961.46     368.95     9225.89     9116.34      109.55         0.00
# 21      62035.06     741.08    11847.02    11768.52       78.50         0.00
# 22      91949.05     966.61    13192.69    13061.53      131.16         0.00
# 23      82049.40    2238.02    11287.48    11103.49      183.99         0.00
# 24      94693.52    4257.64    24431.90    24290.08      108.49        33.33
# 25      72600.55    5883.16    29898.96    29663.19      235.77         0.00
# 26      57545.79    4662.71    26662.08    26311.76      350.32         0.00
# 27      76688.55    5481.18    21875.65    21662.00      213.65         0.00
# 28      55400.94    4377.19    29002.59    28343.14      659.45         0.00
# 29      99220.82      90.32    22775.21    22314.99      460.22         0.00
# ...          ...        ...         ...         ...         ...          ...
# 1487  1958358.83  358015.82  1944064.32  1740557.05   183825.53     19681.74
# 1488  2247248.19  334735.17  1673304.45  1454479.46   201547.46     17277.53
# 1489  2149391.86  311356.91  2207293.04  1926353.76   259874.87     21064.41
# 1490  2191468.26  299002.93  2092117.55  1883192.26   189928.31     18996.98
# 1491  1855262.70  317337.27  2094020.39  1888085.99   186807.69     19126.71
# 1492  1975668.02  325582.20  2234832.81  1981931.04   230048.66     22853.11
# 1493  2020327.87  302210.56  2391861.16  2091747.51   282242.79     17870.86
# 1494  2073957.12  267508.94  2256053.97  2073467.05   167309.24     15277.68
# 1495  1974912.11  278558.48  2555662.85  2207054.69   333029.79     15578.37
# 1496  3950852.38  424389.60  3056112.91  2693843.02   344774.59     17495.30
# 1497  2069192.92  287234.03  2024180.16  1874982.24   134692.75     14505.17
# 1498  2457751.77  272665.17  2285895.60  2122673.09   147881.99     15340.52
# 1499  2336705.19  250106.17  1759854.18  1579233.60   162289.68     18330.90
# 1500  2173554.18  261931.07  2131753.56  1793640.16   321613.97     16499.43
# 1501  2856102.41  257268.16  2301885.36  1950428.50   340852.13     10604.73
# 1502    50792.48    7324.64    61550.33    51247.91    10232.98        69.44
# 1503    46276.63    7942.68    54652.82    44604.56    10048.26         0.00
# 1504    40971.14    8696.54    52402.49    46293.11     6109.38         0.00
# 1505    46285.90    9451.98    59783.11    48016.74    11766.37         0.00
# 1506    34346.09    8265.03    49866.72    44005.31     5861.41         0.00
# 1507    28907.47   13913.04    48742.91    42721.62     6021.29         0.00
# 1508    26597.39   22714.68    45377.66    38436.79     6940.87         0.00
# 1509    27501.34   25305.86    52447.98    45861.67     6586.31         0.00
# 1510    29382.30   26881.22    47315.53    40258.68     6816.57       240.28
# 1511    39749.81   20290.31    52719.25    47060.46     5658.79         0.00
# 1512    56366.66   17531.78    59418.46    48823.53    10354.65       240.28
# 1513    52189.61   19419.57    63300.70    54704.14     8596.56         0.00
# 1514    52893.38   16736.92    62415.77    53332.61     8258.16       825.00
# 1515    53593.58   17495.42    63931.73    55653.47     8278.26         0.00
# 1516    54193.42   16563.91    69104.56    57456.21    11648.35         0.00
#
#               type  year      region
# 0     conventional  2015      Albany
# 1     conventional  2015      Albany
# 2     conventional  2015      Albany
# 3     conventional  2015      Albany
# 4     conventional  2015      Albany
# 5     conventional  2015      Albany
# 6     conventional  2015      Albany
# 7     conventional  2015      Albany
# 8     conventional  2015      Albany
# 9     conventional  2015      Albany
# 10    conventional  2015      Albany
# 11    conventional  2015      Albany
# 12    conventional  2015      Albany
# 13    conventional  2015      Albany
# 14    conventional  2015      Albany
# 15    conventional  2015      Albany
# 16    conventional  2015      Albany
# 17    conventional  2015      Albany
# 18    conventional  2015      Albany
# 19    conventional  2015      Albany
# 20    conventional  2015      Albany
# 21    conventional  2015      Albany
# 22    conventional  2015      Albany
# 23    conventional  2015      Albany
# 24    conventional  2015      Albany
# 25    conventional  2015      Albany
# 26    conventional  2015      Albany
# 27    conventional  2015      Albany
# 28    conventional  2015      Albany
# 29    conventional  2015      Albany
# ...            ...   ...         ...
# 1487  conventional  2016  California
# 1488  conventional  2016  California
# 1489  conventional  2016  California
# 1490  conventional  2016  California
# 1491  conventional  2016  California
# 1492  conventional  2016  California
# 1493  conventional  2016  California
# 1494  conventional  2016  California
# 1495  conventional  2016  California
# 1496  conventional  2016  California
# 1497  conventional  2016  California
# 1498  conventional  2016  California
# 1499  conventional  2016  California
# 1500  conventional  2016  California
# 1501  conventional  2016  California
# 1502  conventional  2016   Charlotte
# 1503  conventional  2016   Charlotte
# 1504  conventional  2016   Charlotte
# 1505  conventional  2016   Charlotte
# 1506  conventional  2016   Charlotte
# 1507  conventional  2016   Charlotte
# 1508  conventional  2016   Charlotte
# 1509  conventional  2016   Charlotte
# 1510  conventional  2016   Charlotte
# 1511  conventional  2016   Charlotte
# 1512  conventional  2016   Charlotte
# 1513  conventional  2016   Charlotte
# 1514  conventional  2016   Charlotte
# 1515  conventional  2016   Charlotte
# 1516  conventional  2016   Charlotte
#
# [1517 rows x 14 columns]

# %%
ds.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517 entries, 0 to 1516
# Data columns (total 14 columns):
# Unnamed: 0      1517 non-null int64
# Date            1517 non-null object
# AveragePrice    1517 non-null float64
# Total Volume    1517 non-null float64
# 4046            1517 non-null float64
# 4225            1517 non-null float64
# 4770            1517 non-null float64
# Total Bags      1517 non-null float64
# Small Bags      1517 non-null float64
# Large Bags      1517 non-null float64
# XLarge Bags     1517 non-null float64
# type            1517 non-null object
# year            1517 non-null int64
# region          1517 non-null object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 166.0+ KB

# %% [markdown]
# We need to handle Date column by seperating year,month and day in seperate columns

# %%
ds.describe()
# Out:
#         Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  1517.000000   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03
# mean     26.995386      1.074990  1.601879e+06  6.464387e+05  6.114375e+05
# std      14.848287      0.188891  4.433143e+06  1.947614e+06  1.672906e+06
# min       0.000000      0.490000  3.875074e+04  4.677200e+02  1.783770e+03
# 25%      14.000000      0.980000  1.474700e+05  2.040034e+04  4.147606e+04
# 50%      29.000000      1.080000  4.027919e+05  8.175117e+04  1.186649e+05
# 75%      39.000000      1.190000  9.819751e+05  3.775785e+05  4.851503e+05
# max      51.000000      1.680000  4.465546e+07  1.893304e+07  1.895648e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000
# mean   5.040550e+04  2.935974e+05  2.487736e+05  4.264205e+04    2181.771074
# std    1.377812e+05  7.579765e+05  6.474765e+05  1.182157e+05    7455.712144
# min    0.000000e+00  3.311770e+03  3.311770e+03  0.000000e+00       0.000000
# 25%    9.112500e+02  3.620689e+04  2.972722e+04  5.407400e+02       0.000000
# 50%    7.688170e+03  7.397906e+04  6.237569e+04  5.044350e+03       0.000000
# 75%    2.916730e+04  1.576097e+05  1.461994e+05  2.926767e+04     401.480000
# max    1.381516e+06  6.736304e+06  5.893642e+06  1.121076e+06  108072.790000
#
#               year
# count  1517.000000
# mean   2015.162821
# std       0.369324
# min    2015.000000
# 25%    2015.000000
# 50%    2015.000000
# 75%    2015.000000
# max    2016.000000

# %%
ds['year']=pd.DatetimeIndex(ds['Date']).year
ds['month']=pd.DatetimeIndex(ds['Date']).month
ds['day']=pd.DatetimeIndex(ds['Date']).day

# %%
ds.drop(['Date'],inplace=True,axis=1)

# %%
ds
# Out:
#       Unnamed: 0  AveragePrice  Total Volume        4046        4225  \
# 0              0          1.33      64236.62     1036.74    54454.85
# 1              1          1.35      54876.98      674.28    44638.81
# 2              2          0.93     118220.22      794.70   109149.67
# 3              3          1.08      78992.15     1132.00    71976.41
# 4              4          1.28      51039.60      941.48    43838.39
# 5              5          1.26      55979.78     1184.27    48067.99
# 6              6          0.99      83453.76     1368.92    73672.72
# 7              7          0.98     109428.33      703.75   101815.36
# 8              8          1.02      99811.42     1022.15    87315.57
# 9              9          1.07      74338.76      842.40    64757.44
# 10            10          1.12      84843.44      924.86    75595.85
# 11            11          1.28      64489.17     1582.03    52677.92
# 12            12          1.31      61007.10     2268.32    49880.67
# 13            13          0.99     106803.39     1204.88    99409.21
# 14            14          1.33      69759.01     1028.03    59313.12
# 15            15          1.28      76111.27      985.73    65696.86
# 16            16          1.11      99172.96      879.45    90062.62
# 17            17          1.07     105693.84      689.01    94362.67
# 18            18          1.34      79992.09      733.16    67933.79
# 19            19          1.33      80043.78      539.65    68666.01
# 20            20          1.12     111140.93      584.63   100961.46
# 21            21          1.45      75133.10      509.94    62035.06
# 22            22          1.11     106757.10      648.75    91949.05
# 23            23          1.26      96617.00     1042.10    82049.40
# 24            24          1.05     124055.31      672.25    94693.52
# 25            25          1.35     109252.12      869.45    72600.55
# 26            26          1.37      89534.81      664.23    57545.79
# 27            27          1.27     104849.39      804.01    76688.55
# 28            28          1.32      89631.30      850.58    55400.94
# 29            29          1.07     122743.06      656.71    99220.82
# ...          ...           ...           ...         ...         ...
# 1487          37          0.94    6509000.56  2248561.59  1958358.83
# 1488          38          0.93    6060843.76  1805555.95  2247248.19
# 1489          39          0.93    6603707.93  1935666.12  2149391.86
# 1490          40          0.91    6476206.54  1893617.80  2191468.26
# 1491          41          0.96    6017563.88  1750943.52  1855262.70
# 1492          42          0.92    6429870.23  1893787.20  1975668.02
# 1493          43          0.89    6588277.70  1873878.11  2020327.87
# 1494          44          0.89    6374019.03  1776499.00  2073957.12
# 1495          45          0.82    6807283.15  1998149.71  1974912.11
# 1496          46          0.70   10361698.17  2930343.28  3950852.38
# 1497          47          0.88    6506673.96  2126066.85  2069192.92
# 1498          48          0.88    6246380.73  1230068.19  2457751.77
# 1499          49          0.90    6000013.23  1653347.69  2336705.19
# 1500          50          0.87    6303406.82  1736168.01  2173554.18
# 1501          51          0.73    7730431.28  2315175.35  2856102.41
# 1502           0          1.25     155793.03    36125.58    50792.48
# 1503           1          1.24     144634.01    35761.88    46276.63
# 1504           2          1.33     145815.04    43744.87    40971.14
# 1505           3          1.34     154742.81    39221.82    46285.90
# 1506           4          1.54     131453.85    38976.01    34346.09
# 1507           5          1.57     135608.11    44044.69    28907.47
# 1508           6          1.64     144089.12    49399.39    26597.39
# 1509           7          1.57     142095.92    36840.74    27501.34
# 1510           8          1.58     142955.49    39376.44    29382.30
# 1511           9          1.52     167741.27    54981.90    39749.81
# 1512          10          1.39     190846.01    57529.11    56366.66
# 1513          11          1.51     178235.75    43325.87    52189.61
# 1514          12          1.48     178410.82    46364.75    52893.38
# 1515          13          1.47     189131.52    54110.79    53593.58
# 1516          14          1.43     182978.30    43116.41    54193.42
#
#            4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 0         48.16     8696.87     8603.62       93.25         0.00
# 1         58.33     9505.56     9408.07       97.49         0.00
# 2        130.50     8145.35     8042.21      103.14         0.00
# 3         72.58     5811.16     5677.40      133.76         0.00
# 4         75.78     6183.95     5986.26      197.69         0.00
# 5         43.61     6683.91     6556.47      127.44         0.00
# 6         93.26     8318.86     8196.81      122.05         0.00
# 7         80.00     6829.22     6266.85      562.37         0.00
# 8         85.34    11388.36    11104.53      283.83         0.00
# 9        113.00     8625.92     8061.47      564.45         0.00
# 10       117.07     8205.66     7877.86      327.80         0.00
# 11       105.32    10123.90     9866.27      257.63         0.00
# 12       101.36     8756.75     8379.98      376.77         0.00
# 13       154.84     6034.46     5888.87      145.59         0.00
# 14       150.50     9267.36     8489.10      778.26         0.00
# 15       142.00     9286.68     8665.19      621.49         0.00
# 16       240.79     7990.10     7762.87      227.23         0.00
# 17       335.43    10306.73    10218.93       87.80         0.00
# 18       444.78    10880.36    10745.79      134.57         0.00
# 19       394.90    10443.22    10297.68      145.54         0.00
# 20       368.95     9225.89     9116.34      109.55         0.00
# 21       741.08    11847.02    11768.52       78.50         0.00
# 22       966.61    13192.69    13061.53      131.16         0.00
# 23      2238.02    11287.48    11103.49      183.99         0.00
# 24      4257.64    24431.90    24290.08      108.49        33.33
# 25      5883.16    29898.96    29663.19      235.77         0.00
# 26      4662.71    26662.08    26311.76      350.32         0.00
# 27      5481.18    21875.65    21662.00      213.65         0.00
# 28      4377.19    29002.59    28343.14      659.45         0.00
# 29        90.32    22775.21    22314.99      460.22         0.00
# ...         ...         ...         ...         ...          ...
# 1487  358015.82  1944064.32  1740557.05   183825.53     19681.74
# 1488  334735.17  1673304.45  1454479.46   201547.46     17277.53
# 1489  311356.91  2207293.04  1926353.76   259874.87     21064.41
# 1490  299002.93  2092117.55  1883192.26   189928.31     18996.98
# 1491  317337.27  2094020.39  1888085.99   186807.69     19126.71
# 1492  325582.20  2234832.81  1981931.04   230048.66     22853.11
# 1493  302210.56  2391861.16  2091747.51   282242.79     17870.86
# 1494  267508.94  2256053.97  2073467.05   167309.24     15277.68
# 1495  278558.48  2555662.85  2207054.69   333029.79     15578.37
# 1496  424389.60  3056112.91  2693843.02   344774.59     17495.30
# 1497  287234.03  2024180.16  1874982.24   134692.75     14505.17
# 1498  272665.17  2285895.60  2122673.09   147881.99     15340.52
# 1499  250106.17  1759854.18  1579233.60   162289.68     18330.90
# 1500  261931.07  2131753.56  1793640.16   321613.97     16499.43
# 1501  257268.16  2301885.36  1950428.50   340852.13     10604.73
# 1502    7324.64    61550.33    51247.91    10232.98        69.44
# 1503    7942.68    54652.82    44604.56    10048.26         0.00
# 1504    8696.54    52402.49    46293.11     6109.38         0.00
# 1505    9451.98    59783.11    48016.74    11766.37         0.00
# 1506    8265.03    49866.72    44005.31     5861.41         0.00
# 1507   13913.04    48742.91    42721.62     6021.29         0.00
# 1508   22714.68    45377.66    38436.79     6940.87         0.00
# 1509   25305.86    52447.98    45861.67     6586.31         0.00
# 1510   26881.22    47315.53    40258.68     6816.57       240.28
# 1511   20290.31    52719.25    47060.46     5658.79         0.00
# 1512   17531.78    59418.46    48823.53    10354.65       240.28
# 1513   19419.57    63300.70    54704.14     8596.56         0.00
# 1514   16736.92    62415.77    53332.61     8258.16       825.00
# 1515   17495.42    63931.73    55653.47     8278.26         0.00
# 1516   16563.91    69104.56    57456.21    11648.35         0.00
#
#               type  year      region  month  day
# 0     conventional  2015      Albany     12   27
# 1     conventional  2015      Albany     12   20
# 2     conventional  2015      Albany     12   13
# 3     conventional  2015      Albany      6   12
# 4     conventional  2015      Albany     11   29
# 5     conventional  2015      Albany     11   22
# 6     conventional  2015      Albany     11   15
# 7     conventional  2015      Albany      8   11
# 8     conventional  2015      Albany      1   11
# 9     conventional  2015      Albany     10   25
# 10    conventional  2015      Albany     10   18
# 11    conventional  2015      Albany     11   10
# 12    conventional  2015      Albany      4   10
# 13    conventional  2015      Albany      9   27
# 14    conventional  2015      Albany      9   20
# 15    conventional  2015      Albany      9   13
# 16    conventional  2015      Albany      6    9
# 17    conventional  2015      Albany      8   30
# 18    conventional  2015      Albany      8   23
# 19    conventional  2015      Albany      8   16
# 20    conventional  2015      Albany      9    8
# 21    conventional  2015      Albany      2    8
# 22    conventional  2015      Albany      7   26
# 23    conventional  2015      Albany      7   19
# 24    conventional  2015      Albany     12    7
# 25    conventional  2015      Albany      5    7
# 26    conventional  2015      Albany      6   28
# 27    conventional  2015      Albany      6   21
# 28    conventional  2015      Albany      6   14
# 29    conventional  2015      Albany      7    6
# ...            ...   ...         ...    ...  ...
# 1487  conventional  2016  California     10    4
# 1488  conventional  2016  California      3    4
# 1489  conventional  2016  California      3   27
# 1490  conventional  2016  California      3   20
# 1491  conventional  2016  California      3   13
# 1492  conventional  2016  California      6    3
# 1493  conventional  2016  California      2   28
# 1494  conventional  2016  California      2   21
# 1495  conventional  2016  California      2   14
# 1496  conventional  2016  California      7    2
# 1497  conventional  2016  California      1   31
# 1498  conventional  2016  California      1   24
# 1499  conventional  2016  California      1   17
# 1500  conventional  2016  California     10    1
# 1501  conventional  2016  California      3    1
# 1502  conventional  2016   Charlotte     12   25
# 1503  conventional  2016   Charlotte     12   18
# 1504  conventional  2016   Charlotte     11   12
# 1505  conventional  2016   Charlotte      4   12
# 1506  conventional  2016   Charlotte     11   27
# 1507  conventional  2016   Charlotte     11   20
# 1508  conventional  2016   Charlotte     11   13
# 1509  conventional  2016   Charlotte      6   11
# 1510  conventional  2016   Charlotte     10   30
# 1511  conventional  2016   Charlotte     10   23
# 1512  conventional  2016   Charlotte     10   16
# 1513  conventional  2016   Charlotte      9   10
# 1514  conventional  2016   Charlotte      2   10
# 1515  conventional  2016   Charlotte      9   25
# 1516  conventional  2016   Charlotte      9   18
#
# [1517 rows x 15 columns]

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517 entries, 0 to 1516
# Data columns (total 15 columns):
# Unnamed: 0      1517 non-null int64
# AveragePrice    1517 non-null float64
# Total Volume    1517 non-null float64
# 4046            1517 non-null float64
# 4225            1517 non-null float64
# 4770            1517 non-null float64
# Total Bags      1517 non-null float64
# Small Bags      1517 non-null float64
# Large Bags      1517 non-null float64
# XLarge Bags     1517 non-null float64
# type            1517 non-null object
# year            1517 non-null int64
# region          1517 non-null object
# month           1517 non-null int64
# day             1517 non-null int64
# dtypes: float64(9), int64(4), object(2)
# memory usage: 177.9+ KB

# %%
g1 = ds.groupby(["region"]).size()
g1
# Out:
# region
# Albany                 67
# Atlanta                54
# BaltimoreWashington    65
# Boise                  65
# Boston                 62
# BuffaloRochester       51
# California             76
# Charlotte              31
# Chicago                23
# Columbus               47
# DallasFtWorth          17
# Denver                 24
# Detroit                40
# GrandRapids            23
# GreatLakes             18
# HarrisburgScranton     19
# HartfordSpringfield    13
# Houston                29
# Indianapolis           16
# Jacksonville           41
# LasVegas               10
# LosAngeles              3
# Louisville             34
# MiamiFtLauderdale      17
# Midsouth               18
# Nashville              25
# NewYork                44
# Northeast              12
# NorthernNewEngland     29
# Orlando                21
# Philadelphia           13
# PhoenixTucson          52
# Pittsburgh             22
# Plains                 12
# Portland               30
# RaleighGreensboro      16
# RichmondNorfolk        21
# Roanoke                17
# SanDiego               38
# SanFrancisco           15
# Seattle                 9
# SouthCarolina          24
# SouthCentral           39
# Southeast               9
# Spokane                49
# StLouis                16
# Syracuse               19
# Tampa                  34
# TotalUS                25
# West                   36
# WestTexNewMexico       27
# dtype: int64

# %%
corr=ds.corr()
plt.figure(figsize=(16,5))
sn.heatmap(corr,annot=True,linewidths=.8)
plt.show()

# %% [markdown]
# using correlation heatmap we can observe
# 1.Unnamed:0,AveragePrice,Large Bags and 4225 are highly correlated.
# 2.year is least correlated

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
ds.type=le.fit_transform(ds.type)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
ds.region=le.fit_transform(ds.region)

# %% [markdown]
# Converting categorical columns to numerical using LabelEncoder

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517 entries, 0 to 1516
# Data columns (total 15 columns):
# Unnamed: 0      1517 non-null int64
# AveragePrice    1517 non-null float64
# Total Volume    1517 non-null float64
# 4046            1517 non-null float64
# 4225            1517 non-null float64
# 4770            1517 non-null float64
# Total Bags      1517 non-null float64
# Small Bags      1517 non-null float64
# Large Bags      1517 non-null float64
# XLarge Bags     1517 non-null float64
# type            1517 non-null int32
# year            1517 non-null int64
# region          1517 non-null int32
# month           1517 non-null int64
# day             1517 non-null int64
# dtypes: float64(9), int32(2), int64(4)
# memory usage: 166.0 KB

# %%
sn.boxplot(data=ds["Unnamed: 0"])
plt.show()

# %%
sn.boxplot(data=ds["Total Volume"])
plt.show()

# %%
sn.boxplot(data=ds["4046"])
plt.show()

# %%
sn.boxplot(data=ds["4225"])
plt.show()

# %%
sn.boxplot(data=ds["4770"])
plt.show()

# %%
sn.boxplot(data=ds["Total Bags"])
plt.show()

# %%
sn.boxplot(data=ds["Small Bags"])
plt.show()

# %%
sn.boxplot(data=ds["XLarge Bags"])
plt.show()

# %%
plt.hist(ds['XLarge Bags'])
# Out:
# (array([1.417e+03, 4.700e+01, 3.100e+01, 1.300e+01, 7.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 1.000e+00]),
#  array([     0.   ,  10807.279,  21614.558,  32421.837,  43229.116,
#          54036.395,  64843.674,  75650.953,  86458.232,  97265.511,
#         108072.79 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Columns like "Total Volume,4046,4225,4770,total Bags,Small Bags,XLarge Bags" have outliers.
# We will try to remove outliers using zscore

# %%
plt.show()

# %%
sn.distplot(ds['XLarge Bags'])
plt.show()

# %%
sn.distplot(ds['Unnamed: 0'])
plt.show()

# %% [markdown]
# #Removing outlier using Zscore
# from scipy.stats import zscore
# z=np.abs(zscore(ds))
# threshold=3
# new_ds=ds[(z<3)]

# %%
#creating target variable and seperating data into X and Y
x=ds.drop("region",axis=1)
y=ds['region']

# %% [markdown]
# new_ds.info()

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517 entries, 0 to 1516
# Data columns (total 15 columns):
# Unnamed: 0      1517 non-null int64
# AveragePrice    1517 non-null float64
# Total Volume    1517 non-null float64
# 4046            1517 non-null float64
# 4225            1517 non-null float64
# 4770            1517 non-null float64
# Total Bags      1517 non-null float64
# Small Bags      1517 non-null float64
# Large Bags      1517 non-null float64
# XLarge Bags     1517 non-null float64
# type            1517 non-null int32
# year            1517 non-null int64
# region          1517 non-null int32
# month           1517 non-null int64
# day             1517 non-null int64
# dtypes: float64(9), int32(2), int64(4)
# memory usage: 166.0 KB

# %%
#
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25)

# %%
#Scling data using standardscalar method
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaledx=sc.fit_transform(x)

# %%
#Since the Preprocessing and EDA is done we can build our model using Different Algorithms
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# C:\Users\ajay\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\ajay\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([ 6, 49, 39, 12, 26, 24, 41, 33, 22,  9,  9, 12,  4, 35, 12, 17, 38,
#        14,  6,  6,  5, 42,  1, 38,  7, 39, 17, 24, 43,  7, 37,  7, 50, 19,
#         0,  1,  4,  0, 43,  0,  3,  6, 14, 31,  8, 26, 16, 11, 33, 11, 41,
#         4,  2,  0,  5, 33,  4,  6, 39, 11, 14,  4, 45, 22, 41, 13,  0, 25,
#        39,  4, 47, 26, 31, 11, 27, 47, 32, 36, 15, 18, 33,  7, 14, 17, 23,
#        50, 31, 38,  5,  1, 34, 38, 14,  3,  5,  3, 48, 44, 12,  7, 31,  4,
#         1, 34,  4, 22, 32, 46, 33, 32, 49,  7, 38, 36, 48, 44, 32, 31, 17,
#        12,  3, 31,  2,  0,  5, 31, 44,  1,  6, 16, 38,  0,  1, 47, 19, 40,
#         9,  4,  1, 12,  4,  2, 49, 22,  1,  5,  1, 42,  7, 36, 19, 31, 12,
#         7, 12, 45, 31, 38,  4,  5, 34, 40,  9, 30, 26, 26, 44, 31,  2, 24,
#         7, 24, 27,  2, 25, 12, 42, 19,  5,  6, 31, 25, 14, 22, 48,  2,  2,
#         0,  3, 15,  7, 28, 42,  9,  2, 34, 38, 19, 36, 34, 31, 19, 26,  7,
#         9,  2, 17,  0,  0, 19, 38, 41, 41, 38, 12,  6, 31,  2,  2, 41,  3,
#         3,  6, 44,  6, 48,  2,  9,  2, 44, 42,  3, 15, 38, 44,  0,  4, 30,
#        49,  5, 31, 28, 31, 38,  3, 49, 30,  7, 26,  0,  1,  6, 45, 46,  8,
#        23, 46,  9, 49, 37, 25,  5, 49,  2, 38, 49,  2, 47,  2,  3, 41, 42,
#         9, 45,  5, 49,  3, 16,  3, 18,  9, 43,  0, 19, 31, 49,  0,  4, 44,
#         7,  1, 42, 43,  0,  6, 45, 26, 25, 23,  2, 17, 44, 49, 44, 31, 19,
#        42, 38, 34,  0,  2, 11, 15,  0,  6, 42,  9, 49, 49, 19,  6,  4, 38,
#        44,  0, 11, 17, 12, 19, 31, 36, 50,  6, 28, 43, 23,  6,  2,  0, 19,
#        44, 19,  6,  8, 33, 12,  4, 17, 34,  2, 13, 31, 42, 49,  1, 12,  2,
#         3, 13, 44, 26,  1, 33,  4, 23, 26,  0, 26, 37,  4,  4, 37, 46,  0,
#        50, 34, 27,  9, 23, 42])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98        22
#            1       0.92      0.86      0.89        14
#            2       0.86      1.00      0.92        18
#            3       0.92      0.86      0.89        14
#            4       0.89      0.94      0.91        17
#            5       0.91      1.00      0.95        10
#            6       0.88      0.71      0.79        21
#            7       0.62      1.00      0.76         8
#            8       1.00      1.00      1.00         3
#            9       1.00      0.92      0.96        13
#           10       0.00      0.00      0.00         3
#           11       0.83      1.00      0.91         5
#           12       0.92      0.92      0.92        13
#           13       1.00      1.00      1.00         3
#           14       0.83      1.00      0.91         5
#           15       1.00      1.00      1.00         4
#           16       1.00      1.00      1.00         3
#           17       1.00      0.89      0.94         9
#           18       1.00      1.00      1.00         2
#           19       1.00      1.00      1.00        13
#           20       0.00      0.00      0.00         3
#           22       1.00      1.00      1.00         5
#           23       1.00      1.00      1.00         6
#           24       1.00      0.80      0.89         5
#           25       0.80      0.67      0.73         6
#           26       1.00      1.00      1.00        11
#           27       1.00      1.00      1.00         3
#           28       0.67      0.50      0.57         4
#           29       0.00      0.00      0.00         1
#           30       1.00      1.00      1.00         3
#           31       0.68      0.65      0.67        20
#           32       1.00      1.00      1.00         4
#           33       0.57      1.00      0.73         4
#           34       0.50      0.57      0.53         7
#           35       0.00      0.00      0.00         5
#           36       0.60      0.50      0.55         6
#           37       1.00      0.80      0.89         5
#           38       0.60      0.82      0.69        11
#           39       0.75      0.60      0.67         5
#           40       0.50      1.00      0.67         1
#           41       0.86      1.00      0.92         6
#           42       0.91      0.77      0.83        13
#           43       1.00      1.00      1.00         5
#           44       0.85      1.00      0.92        11
#           45       0.60      1.00      0.75         3
#           46       1.00      1.00      1.00         4
#           47       0.75      1.00      0.86         3
#           48       1.00      1.00      1.00         4
#           49       0.79      1.00      0.88        11
#           50       0.75      0.60      0.67         5
#
#     accuracy                           0.86       380
#    macro avg       0.80      0.83      0.80       380
# weighted avg       0.84      0.86      0.84       380
# C:\Users\ajay\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8552631578947368

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestClassifier
rd=RandomForestClassifier(n_estimators=100)
rd.fit(x_train,y_train)
y_pred=rd.predict(x_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9921052631578947

# %%
from sklearn.svm import SVC   
classifier = SVC(kernel='linear')  

classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(x_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=0,
#     shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = classifier.predict(x_test)
r2score=r2_score(y_test,y_pred)
print(f"Accuracu is {r2score*100}")
# Out:
# Accuracu is 92.39712468612069

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9657894736842105

# %%
#We will try to improve performance of our best model using GridSearchCV
from sklearn.model_selection import GridSearchCV 
   
param_grid = {'C': [0.1, 1, 10, 100, 1000],  
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
              'kernel': ['rbf']}  
  
grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3) 

grid.fit(x_train, y_train)
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# C:\Users\ajay\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.048, total=   0.3s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.047, total=   0.3s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.6s remaining:    0.0s
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.050, total=   0.3s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.048, total=   0.3s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.047, total=   0.3s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.050, total=   0.3s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.048, total=   0.3s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.047, total=   0.4s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.050, total=   0.4s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.048, total=   0.3s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.047, total=   0.3s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.050, total=   0.3s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.048, total=   0.4s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.047, total=   0.5s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.050, total=   0.6s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.048, total=   0.5s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.047, total=   0.5s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.050, total=   0.4s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.048, total=   0.5s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.047, total=   0.5s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.050, total=   0.5s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.048, total=   0.3s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.047, total=   0.3s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.050, total=   0.3s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.048, total=   0.3s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.047, total=   0.3s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.050, total=   0.3s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.048, total=   0.3s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.047, total=   0.3s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.050, total=   0.4s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.048, total=   0.3s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.047, total=   0.3s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.050, total=   0.4s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.048, total=   0.3s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.047, total=   0.4s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.050, total=   0.4s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.048, total=   0.3s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.047, total=   0.3s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.050, total=   0.4s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.048, total=   0.3s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.047, total=   0.4s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.050, total=   0.4s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.048, total=   0.4s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.047, total=   0.3s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.050, total=   0.4s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.048, total=   0.3s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.047, total=   0.4s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.050, total=   0.4s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.048, total=   0.5s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.047, total=   0.3s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.050, total=   0.4s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.048, total=   0.3s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.047, total=   0.4s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.050, total=   0.4s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.048, total=   0.4s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.047, total=   0.4s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.050, total=   0.7s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.048, total=   0.5s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.047, total=   0.8s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.050, total=   0.5s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.048, total=   0.3s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.047, total=   0.5s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.050, total=   0.6s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.048, total=   0.5s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.047, total=   0.4s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.050, total=   0.4s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.048, total=   0.4s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.047, total=   0.4s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.050, total=   0.4s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.048, total=   0.4s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.047, total=   0.4s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.050, total=   0.4s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.048, total=   0.4s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.047, total=   0.4s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.050, total=   0.4s
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed:   29.6s finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='auto_deprecated', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
# print best parameter after tuning 
print(grid.best_params_) 
  
# print how our model looks after hyper-parameter tuning 
print(grid.best_estimator_)
# Out:
# {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=1, kernel='rbf', max_iter=-1,
#     probability=False, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)

# %%
predictions = grid.predict(x_test)
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        22
#            1       0.00      0.00      0.00        14
#            2       0.00      0.00      0.00        18
#            3       0.00      0.00      0.00        14
#            4       0.00      0.00      0.00        17
#            5       0.00      0.00      0.00        10
#            6       0.06      1.00      0.10        21
#            7       0.00      0.00      0.00         8
#            8       0.00      0.00      0.00         3
#            9       0.00      0.00      0.00        13
#           10       0.00      0.00      0.00         3
#           11       0.00      0.00      0.00         5
#           12       0.00      0.00      0.00        13
#           13       0.00      0.00      0.00         3
#           14       0.00      0.00      0.00         5
#           15       0.00      0.00      0.00         4
#           16       0.00      0.00      0.00         3
#           17       0.00      0.00      0.00         9
#           18       0.00      0.00      0.00         2
#           19       0.00      0.00      0.00        13
#           20       0.00      0.00      0.00         3
#           22       0.00      0.00      0.00         5
#           23       0.00      0.00      0.00         6
#           24       0.00      0.00      0.00         5
#           25       0.00      0.00      0.00         6
#           26       0.00      0.00      0.00        11
#           27       0.00      0.00      0.00         3
#           28       0.00      0.00      0.00         4
#           29       0.00      0.00      0.00         1
#           30       0.00      0.00      0.00         3
#           31       0.00      0.00      0.00        20
#           32       0.00      0.00      0.00         4
#           33       0.00      0.00      0.00         4
#           34       0.00      0.00      0.00         7
#           35       0.00      0.00      0.00         5
#           36       0.00      0.00      0.00         6
#           37       0.00      0.00      0.00         5
#           38       0.00      0.00      0.00        11
#           39       0.00      0.00      0.00         5
#           40       0.00      0.00      0.00         1
#           41       0.00      0.00      0.00         6
#           42       0.00      0.00      0.00        13
#           43       0.00      0.00      0.00         5
#           44       0.00      0.00      0.00        11
#           45       0.00      0.00      0.00         3
#           46       0.00      0.00      0.00         4
#           47       0.00      0.00      0.00         3
#           48       0.00      0.00      0.00         4
#           49       0.00      0.00      0.00        11
#           50       0.00      0.00      0.00         5
#
#     accuracy                           0.06       380
#    macro avg       0.00      0.02      0.00       380
# weighted avg       0.00      0.06      0.01       380
# C:\Users\ajay\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# Regression

# %%
x=ds.drop("AveragePrice",axis=1)
y=ds['AveragePrice']

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517 entries, 0 to 1516
# Data columns (total 15 columns):
# Unnamed: 0      1517 non-null int64
# AveragePrice    1517 non-null float64
# Total Volume    1517 non-null float64
# 4046            1517 non-null float64
# 4225            1517 non-null float64
# 4770            1517 non-null float64
# Total Bags      1517 non-null float64
# Small Bags      1517 non-null float64
# Large Bags      1517 non-null float64
# XLarge Bags     1517 non-null float64
# type            1517 non-null int32
# year            1517 non-null int64
# region          1517 non-null int32
# month           1517 non-null int64
# day             1517 non-null int64
# dtypes: float64(9), int32(2), int64(4)
# memory usage: 166.0 KB

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lin=LinearRegression()
lin.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = lin.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
R2 =r2_score(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)
lin.score(x_test,y_test)
score=rd.score(x_test,y_test)
print('R2: ',R2)
print('RMSE: ',rmse)
print('Score: ',score)
# Out:
# R2:  0.797105375663357
# RMSE:  0.008074374236842104
# Score:  0.797105375663357

# %%
from sklearn.ensemble import RandomForestRegressor
rd=RandomForestRegressor(n_estimators = 100, random_state = 42)
rd.fit(x_train,y_train)
y_pred=rd.predict(x_test)

# %%
R2 =r2_score(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)
score=rd.score(x_test,y_test)
print('R2: ',R2)
print('RMSE: ',rmse)
print('Score: ',score)
# Out:
# R2:  0.797105375663357
# RMSE:  0.008074374236842104
# Score:  0.797105375663357

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(x_train,y_train)
svr_y_pred=rd.predict(x_test)
# Out:
# C:\Users\ajay\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
R2 =r2_score(y_test, svr_y_pred)
rmse = mean_squared_error(y_test, svr_y_pred)
score=rd.score(x_test,svr_y_pred)
print('R2: ',R2)
print('RMSE: ',rmse)
print('Score: ',score)
# Out:
# R2:  0.797105375663357
# RMSE:  0.008074374236842104
# Score:  1.0

# %% [markdown]
#  Model Saving

# %%
#Creating pickle file
import pickle
filename='avacado.pkl'
pickle.dump(regressor,open(filename,'wb'))

# %% [markdown]
# Conclusion

# %%
a=np.array(y_test)
a
# Out:
# array([1.03, 1.1 , 1.07, 1.34, 1.22, 0.95, 0.91, 1.22, 1.22, 1.17, 0.89,
#        1.18, 1.09, 1.17, 1.05, 0.89, 1.31, 0.96, 1.2 , 0.96, 1.06, 1.34,
#        1.21, 1.1 , 0.88, 1.02, 0.68, 1.11, 1.03, 1.18, 0.93, 0.73, 1.23,
#        1.22, 1.39, 0.91, 1.05, 1.33, 0.93, 0.93, 1.43, 1.1 , 0.98, 1.08,
#        0.99, 1.24, 1.06, 1.68, 1.37, 0.89, 1.29, 1.13, 1.2 , 0.97, 1.18,
#        1.16, 1.11, 0.58, 0.96, 0.99, 1.06, 1.2 , 1.31, 1.25, 0.95, 1.18,
#        1.19, 1.05, 1.24, 1.16, 1.08, 1.08, 1.36, 1.19, 0.94, 0.96, 1.11,
#        1.11, 0.88, 1.63, 1.53, 1.04, 1.08, 1.19, 1.19, 1.2 , 1.11, 1.4 ,
#        1.1 , 0.92, 0.96, 1.34, 0.91, 1.  , 1.17, 1.06, 0.99, 0.86, 1.19,
#        1.34, 0.85, 1.4 , 1.1 , 1.35, 0.92, 1.08, 1.19, 1.11, 0.75, 1.33,
#        1.45, 0.76, 1.19, 1.38, 0.93, 0.96, 0.97, 1.09, 1.15, 1.13, 1.  ,
#        1.09, 1.04, 1.33, 1.09, 1.38, 0.8 , 1.22, 1.07, 1.16, 0.79, 1.03,
#        0.97, 0.93, 1.14, 1.01, 1.18, 1.15, 1.11, 1.28, 1.16, 1.24, 0.97,
#        0.97, 0.99, 1.13, 1.29, 1.16, 0.75, 1.03, 1.33, 0.67, 1.01, 1.19,
#        0.92, 1.17, 1.09, 1.22, 1.3 , 0.8 , 0.8 , 1.21, 0.97, 1.03, 1.05,
#        0.96, 0.77, 1.21, 1.19, 1.21, 1.23, 1.06, 1.26, 0.62, 1.15, 1.11,
#        0.71, 1.12, 0.85, 1.11, 1.09, 1.41, 1.33, 1.32, 1.01, 0.93, 0.99,
#        0.95, 0.9 , 0.95, 1.11, 1.13, 1.3 , 1.27, 0.72, 1.01, 1.27, 1.03,
#        1.2 , 1.27, 0.99, 1.04, 1.28, 0.97, 0.84, 0.78, 0.9 , 1.34, 1.  ,
#        0.93, 0.72, 1.1 , 1.21, 1.18, 0.7 , 1.  , 1.25, 1.01, 1.22, 1.21,
#        1.16, 1.02, 1.17, 0.9 , 1.34, 1.1 , 1.03, 1.06, 1.03, 1.33, 1.02,
#        1.12, 1.1 , 1.23, 1.24, 1.25, 1.18, 1.05, 1.14, 1.14, 1.35, 1.18,
#        1.09, 0.98, 0.7 , 1.08, 1.06, 1.05, 1.12, 0.99, 1.27, 1.09, 1.18,
#        1.43, 1.07, 0.76, 1.27, 1.06, 1.21, 0.99, 1.18, 1.07, 1.02, 1.52,
#        1.48, 1.24, 1.05, 1.16, 0.98, 1.23, 0.57, 0.99, 1.16, 0.92, 1.04,
#        1.06, 0.65, 1.26, 0.7 , 1.23, 1.58, 0.79, 0.53, 0.72, 0.49, 0.58,
#        0.77, 0.6 , 1.33, 0.93, 0.94, 0.93, 1.09, 1.08, 1.15, 1.61, 0.97,
#        1.34, 1.02, 0.98, 1.05, 0.97, 0.83, 0.97, 0.84, 0.97, 1.2 , 1.26,
#        0.99, 1.27, 1.36, 1.19, 1.07, 1.15, 0.94, 1.46, 1.1 , 1.01, 1.05,
#        1.04, 1.14, 1.18, 1.02, 0.93, 1.27, 1.32, 1.11, 0.94, 1.27, 0.85,
#        0.92, 1.38, 1.32, 1.17, 1.12, 1.13, 1.24, 1.08, 0.93, 1.04, 1.32,
#        1.57, 0.99, 0.98, 1.15, 1.1 , 1.2 , 1.1 , 1.04, 1.  , 1.08, 1.15,
#        1.07, 1.05, 1.11, 0.89, 1.18, 1.41, 1.14, 1.  , 1.25, 1.26, 0.98,
#        1.08, 0.71, 1.44, 1.51, 1.33, 0.78, 1.25, 0.75, 0.92, 0.52, 1.19,
#        0.56, 1.63, 0.67, 1.14, 0.74, 1.18])

# %%
predicted=np.array(regressor.predict(x_test))
predicted
# Out:
# array([1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793,
#        1.06697793, 1.06697793, 1.06697793, 1.06697793, 1.06697793])

# %%
#Comparing original and predicted values
con=pd.DataFrame({"Original" : a,"Predicted":predicted},index=range(len(a)))
con
# Out:
#      Original  Predicted
# 0        1.03   1.066978
# 1        1.10   1.066978
# 2        1.07   1.066978
# 3        1.34   1.066978
# 4        1.22   1.066978
# 5        0.95   1.066978
# 6        0.91   1.066978
# 7        1.22   1.066978
# 8        1.22   1.066978
# 9        1.17   1.066978
# 10       0.89   1.066978
# 11       1.18   1.066978
# 12       1.09   1.066978
# 13       1.17   1.066978
# 14       1.05   1.066978
# 15       0.89   1.066978
# 16       1.31   1.066978
# 17       0.96   1.066978
# 18       1.20   1.066978
# 19       0.96   1.066978
# 20       1.06   1.066978
# 21       1.34   1.066978
# 22       1.21   1.066978
# 23       1.10   1.066978
# 24       0.88   1.066978
# 25       1.02   1.066978
# 26       0.68   1.066978
# 27       1.11   1.066978
# 28       1.03   1.066978
# 29       1.18   1.066978
# ..        ...        ...
# 350      1.08   1.066978
# 351      1.15   1.066978
# 352      1.07   1.066978
# 353      1.05   1.066978
# 354      1.11   1.066978
# 355      0.89   1.066978
# 356      1.18   1.066978
# 357      1.41   1.066978
# 358      1.14   1.066978
# 359      1.00   1.066978
# 360      1.25   1.066978
# 361      1.26   1.066978
# 362      0.98   1.066978
# 363      1.08   1.066978
# 364      0.71   1.066978
# 365      1.44   1.066978
# 366      1.51   1.066978
# 367      1.33   1.066978
# 368      0.78   1.066978
# 369      1.25   1.066978
# 370      0.75   1.066978
# 371      0.92   1.066978
# 372      0.52   1.066978
# 373      1.19   1.066978
# 374      0.56   1.066978
# 375      1.63   1.066978
# 376      0.67   1.066978
# 377      1.14   1.066978
# 378      0.74   1.066978
# 379      1.18   1.066978
#
# [380 rows x 2 columns]
