# %%
#importing required library
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
#Loading the datatse
ds=pd.read_csv("E:/Datatrained/Evaluation/evaluation/Agriculture/train_agriculture.csv")
ds
# Out:
#              ID  Estimated_Insects_Count  Crop_Type  Soil_Type  \
# 0     F00000001                      188          1          0
# 1     F00000003                      209          1          0
# 2     F00000004                      257          1          0
# 3     F00000005                      257          1          1
# 4     F00000006                      342          1          0
# 5     F00000008                      448          0          1
# 6     F00000009                      448          0          1
# 7     F00000010                      577          1          0
# 8     F00000012                      731          0          0
# 9     F00000020                     1132          1          0
# 10    F00000021                     1212          1          0
# 11    F00000023                     1575          0          0
# 12    F00000024                     1575          0          1
# 13    F00000028                     1575          1          1
# ...

# %%
#Checking all the column names
ds.columns
# Out:
# Index(['ID', 'Estimated_Insects_Count', 'Crop_Type', 'Soil_Type',
#        'Pesticide_Use_Category', 'Number_Doses_Week', 'Number_Weeks_Used',
#        'Number_Weeks_Quit', 'Season', 'Crop_Damage'],
#       dtype='object')

# %%
#Checking for null values
ds.isnull().sum()

#There is are null values in "Number_Weeks_Used" .We will replace null values with mean value of column
# Out:
# ID                           0
# Estimated_Insects_Count      0
# Crop_Type                    0
# Soil_Type                    0
# Pesticide_Use_Category       0
# Number_Doses_Week            0
# Number_Weeks_Used          442
# Number_Weeks_Quit            0
# Season                       0
# Crop_Damage                  0
# dtype: int64

# %%
#Checking the datatype of all columns
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4599 entries, 0 to 4598
# Data columns (total 10 columns):
# ID                         4599 non-null object
# Estimated_Insects_Count    4599 non-null int64
# Crop_Type                  4599 non-null int64
# Soil_Type                  4599 non-null int64
# Pesticide_Use_Category     4599 non-null int64
# Number_Doses_Week          4599 non-null int64
# Number_Weeks_Used          4157 non-null float64
# Number_Weeks_Quit          4599 non-null int64
# Season                     4599 non-null int64
# Crop_Damage                4599 non-null int64
# dtypes: float64(1), int64(8), object(1)
# memory usage: 359.4+ KB

# %% [markdown]
# There is one columns "ID" of datatype object but we will not convert it to int as it is not importand and we will drop it

# %%
#Droping the ID column
ds.drop('ID',inplace=True,axis=1)

# %%
ds
# Out:
#       Estimated_Insects_Count  Crop_Type  Soil_Type  Pesticide_Use_Category  \
# 0                         188          1          0                       1
# 1                         209          1          0                       1
# 2                         257          1          0                       1
# 3                         257          1          1                       1
# 4                         342          1          0                       1
# 5                         448          0          1                       1
# 6                         448          0          1                       1
# 7                         577          1          0                       1
# 8                         731          0          0                       1
# 9                        1132          1          0                       1
# 10                       1212          1          0                       1
# ...

# %%
#Filling null values with mean
ds['Number_Weeks_Used'].fillna(value=ds['Number_Weeks_Used'].mean(), inplace=True)

# %%
#checking unique values in Number_Weeks_Used
ds['Number_Weeks_Used'].unique()
# Out:
# array([ 0.        , 28.89102718, 26.        , 20.        , 15.        ,
#        14.        , 19.        , 24.        ,  8.        , 23.        ,
#        25.        , 28.        , 29.        , 22.        , 21.        ,
#        17.        , 30.        , 35.        , 32.        , 27.        ,
#        16.        , 31.        , 33.        , 34.        , 39.        ,
#        38.        , 42.        , 40.        , 41.        , 36.        ,
#        44.        , 37.        , 46.        , 45.        , 47.        ,
#        43.        , 50.        , 10.        , 49.        , 53.        ,
#        48.        , 51.        , 54.        , 52.        , 55.        ,
#        56.        , 61.        , 18.        , 57.        , 62.        ,
#        60.        , 63.        , 66.        , 59.        , 64.        ,
#        13.        ,  7.        ,  5.        , 12.        ,  6.        ,
#         9.        , 58.        , 11.        , 65.        ])

# %%
#Observing the mean,min and max values to see the skewness
ds.describe()
# Out:
#        Estimated_Insects_Count    Crop_Type    Soil_Type  \
# count              4599.000000  4599.000000  4599.000000
# mean               1363.000435     0.224831     0.476625
# std                 814.439120     0.417517     0.499508
# min                 150.000000     0.000000     0.000000
# 25%                 731.000000     0.000000     0.000000
# 50%                1212.000000     0.000000     0.000000
# 75%                1786.000000     0.000000     1.000000
# max                4097.000000     1.000000     1.000000
#
#        Pesticide_Use_Category  Number_Doses_Week  Number_Weeks_Used  \
# count             4599.000000        4599.000000        4599.000000
# mean                 2.283540          26.477495          28.891027
# std                  0.471978          15.524647          11.965785
# min                  1.000000           0.000000           0.000000
# 25%                  2.000000          15.000000          20.000000
# ...

# %%
#Checking the outlier using boxplot
sn.boxplot(data=ds['Estimated_Insects_Count'])
plt.show()

# %%
sn.boxplot(data=ds['Number_Weeks_Used'])
plt.show()

# %% [markdown]
# There are few outliers in Estimated_Insects_Count and Number_Weeks_Used

# %%
#Checking the correlation using heatmap
corr=ds.corr()
plt.figure(figsize=(16,5))
sn.heatmap(corr,annot=True,linewidths=.8)
plt.show()

# %% [markdown]
# presticide_use_category has the highest correlation followed by soil type.
# Where are crop type has the lowest correlation.

# %%
#Checking the skewness
from scipy.stats import skew
for col in ds:
    print(col)
    print(skew(ds[col]))
    
    plt.figure()
    sn.distplot(ds[col])
    plt.show()
# Out:
# Estimated_Insects_Count
# 0.9111716875294515
# Crop_Type
# 1.3182631392719049
# Soil_Type
# 0.09360092483816074
# Pesticide_Use_Category
# 0.6783646160934432
# Number_Doses_Week
# 0.9455863453636739
# Number_Weeks_Used
# 0.2785731955547593
# Number_Weeks_Quit
# 0.9194714005554208
# Season
# 0.14479382772144375
# Crop_Damage
# 2.3061801153116845

# %%
#creating target variable and seperating data into X and Y

x=ds.drop("Crop_Damage",axis=1)
y=ds['Crop_Damage']

# %%
#Splitting the dataset in x and y axis
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25)

# %%
#Since the Preprocessing and EDA is done we can build our model using Different Algorithms
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)

y_pred=lr.predict(x_test)
y_pred

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90       941
#            1       0.42      0.07      0.12       185
#            2       0.00      0.00      0.00        24
#
#     accuracy                           0.81      1150
#    macro avg       0.42      0.35      0.34      1150
# weighted avg       0.74      0.81      0.75      1150
#
# Accuracy: 0.8147826086956522
# C:\Users\ajay\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\ajay\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# ...

# %%
# SVC classifier
from sklearn.svm import SVC   
classifier = SVC(kernel='linear')  

classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(x_train, y_train)

y_pred = classifier.predict(x_test)


print(classification_report(y_test, y_pred))
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90       941
#            1       0.00      0.00      0.00       185
#            2       0.00      0.00      0.00        24
#
#     accuracy                           0.82      1150
#    macro avg       0.27      0.33      0.30      1150
# weighted avg       0.67      0.82      0.74      1150
#
# Accuracy: 0.8182608695652174
# C:\Users\ajay\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
#GaussianNB Classifier 
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(x_train, y_train)

y_pred = classifier.predict(x_test)


print(classification_report(y_test, y_pred))
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89       941
#            1       0.41      0.25      0.31       185
#            2       0.00      0.00      0.00        24
#
#     accuracy                           0.80      1150
#    macro avg       0.42      0.39      0.40      1150
# weighted avg       0.76      0.80      0.78      1150
#
# Accuracy: 0.8034782608695652

# %%
# Random Forest Classifier 
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestClassifier
rd=RandomForestClassifier(n_estimators=100)
rd.fit(x_train,y_train)
y_pred=rd.predict(x_test)

print(classification_report(y_test, y_pred))

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89       941
#            1       0.39      0.17      0.23       185
#            2       0.12      0.04      0.06        24
#
#     accuracy                           0.81      1150
#    macro avg       0.45      0.39      0.40      1150
# weighted avg       0.75      0.81      0.77      1150
#
# Accuracy: 0.8052173913043478

# %%
#We will try to improve performance of our best model using GridSearchCV
from sklearn.model_selection import GridSearchCV 
   
param_grid = {'C': [0.1, 1, 10, 100, 1000],  
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
              'kernel': ['rbf']}  
  
grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3) 

grid.fit(x_train, y_train)

# print best parameter after tuning 
print(grid.best_params_) 

predictions = grid.predict(x_test)
print(classification_report(y_test, predictions))

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# C:\Users\ajay\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.834, total=   1.7s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.835, total=   1.6s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.2s remaining:    0.0s
# ...

# %%
# Out:
# Accuracy: 0.8182608695652174

# %% [markdown]
# We have used SVC for hyperparameter tuning and our accuracy has increased to 81.8%

# %%
#saving our best model
import pickle
filename = 'Agriculture.pkl'
pickle.dump(rd,open(filename, 'wb'))

# %% [markdown]
# We will read our Test data now and try to predict using our best saved model

# %%
# Reading the Test data
test_df=pd.read_csv("E:/Datatrained/Evaluation/evaluation/Agriculture/test_agriculture.csv")
test_df
# Out:
#              ID  Estimated_Insects_Count  Crop_Type  Soil_Type  \
# 0     F00000002                      188          1          1
# 1     F00000007                      410          1          1
# 2     F00000011                      626          1          0
# 3     F00000013                      731          1          0
# 4     F00000014                      789          0          0
# 5     F00000015                      851          0          1
# 6     F00000016                      851          1          0
# 7     F00000019                     1056          1          0
# 8     F00000025                     1576          1          0
# 9     F00000026                     1576          1          0
# 10    F00000027                     1576          1          1
# 11    F00000031                     1898          0          1
# 12    F00000032                     1898          1          0
# 13    F00000033                     2016          0          0
# ...

# %%
#finding if there are any null values in test data
test_df.isnull().sum()
# Out:
# ID                           0
# Estimated_Insects_Count      0
# Crop_Type                    0
# Soil_Type                    0
# Pesticide_Use_Category       0
# Number_Doses_Week            0
# Number_Weeks_Used          119
# Number_Weeks_Quit            0
# Season                       0
# dtype: int64

# %%
#Droping the ID column
test_df.drop('ID',inplace=True,axis=1)

# %%
#Replaceing null values of "Number_Weeks_Used" with mean value
test_df['Number_Weeks_Used'].fillna(value=test_df['Number_Weeks_Used'].mean(), inplace=True)

# %%
sn.boxplot(data=test_df['Estimated_Insects_Count'])
plt.show()

# %%
sn.boxplot(data=test_df['Number_Weeks_Used'])
plt.show()

# %%
from scipy.stats import skew
for col in test_df:
    print(col)
    print(skew(test_df[col]))
    
    plt.figure()
    sn.distplot(test_df[col])
    plt.show()
# Out:
# Estimated_Insects_Count
# 1.0972896833088925
# Crop_Type
# 1.5450319009452416
# Soil_Type
# 0.1791970540465592
# Pesticide_Use_Category
# 0.08956255609021539
# Number_Doses_Week
# 0.8709370257178081
# Number_Weeks_Used
# 0.22006733847397872
# Number_Weeks_Quit
# 1.1895228285894228
# Season
# 0.15567741620555045

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1199 entries, 0 to 1198
# Data columns (total 8 columns):
# Estimated_Insects_Count    1199 non-null int64
# Crop_Type                  1199 non-null int64
# Soil_Type                  1199 non-null int64
# Pesticide_Use_Category     1199 non-null int64
# Number_Doses_Week          1199 non-null int64
# Number_Weeks_Used          1199 non-null float64
# Number_Weeks_Quit          1199 non-null int64
# Season                     1199 non-null int64
# dtypes: float64(1), int64(7)
# memory usage: 75.0 KB

# %%
#It can be observed we don`t have any null value now
test_df.isnull().sum()
# Out:
# Estimated_Insects_Count    0
# Crop_Type                  0
# Soil_Type                  0
# Pesticide_Use_Category     0
# Number_Doses_Week          0
# Number_Weeks_Used          0
# Number_Weeks_Quit          0
# Season                     0
# dtype: int64

# %%
test_df
# Out:
#       Estimated_Insects_Count  Crop_Type  Soil_Type  Pesticide_Use_Category  \
# 0                         188          1          1                       1
# 1                         410          1          1                       1
# 2                         626          1          0                       1
# 3                         731          1          0                       1
# 4                         789          0          0                       1
# 5                         851          0          1                       1
# 6                         851          1          0                       1
# 7                        1056          1          0                       1
# 8                        1576          1          0                       1
# 9                        1576          1          0                       1
# 10                       1576          1          1                       1
# ...

# %%
fitted_model=pickle.load(open("Agriculture.pkl","rb"))

# %%
#our model
fitted_model
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
#giving our test data to model for prediction
predictions=fitted_model.predict(test_df)

# %%
#Our predictions
print("Our predictions are :",predictions)
# Out:
# Our predictions are : [1 1 1 ... 0 0 0]
