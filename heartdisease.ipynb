# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
ds=pd.read_csv("E:/Datatrained/Evaluation/heartdisease.csv",na_values = "?")
ds
# Out:
#      63  1  4    140    260    0  1.1    112  1.2    3    2    ?  ?.1  2.1
# 0    44  1  4  130.0  209.0  0.0    1  127.0  0.0  0.0  NaN  NaN  NaN    0
# 1    60  1  4  132.0  218.0  0.0    1  140.0  1.0  1.5  3.0  NaN  NaN    2
# 2    55  1  4  142.0  228.0  0.0    1  149.0  1.0  2.5  1.0  NaN  NaN    1
# 3    66  1  3  110.0  213.0  1.0    2   99.0  1.0  1.3  2.0  NaN  NaN    0
# 4    66  1  3  120.0    0.0  0.0    1  120.0  0.0 -0.5  1.0  NaN  NaN    0
# 5    65  1  4  150.0  236.0  1.0    1  105.0  1.0  0.0  NaN  NaN  NaN    3
# 6    60  1  3  180.0    0.0  0.0    1  140.0  1.0  1.5  2.0  NaN  NaN    0
# 7    60  1  3  120.0    0.0  NaN    0  141.0  1.0  2.0  1.0  NaN  NaN    3
# 8    60  1  2  160.0  267.0  1.0    1  157.0  0.0  0.5  2.0  NaN  NaN    1
# 9    56  1  2  126.0  166.0  0.0    1  140.0  0.0  0.0  NaN  NaN  NaN    0
# 10   59  1  4  140.0    0.0  0.0    1  117.0  1.0  1.0  2.0  NaN  NaN    1
# 11   62  1  4  110.0    0.0  0.0    0  120.0  1.0  0.5  2.0  NaN  3.0    1
# 12   63  1  3    NaN    0.0  0.0    2    NaN  NaN  NaN  NaN  NaN  NaN    1
# 13   57  1  4  128.0    0.0  1.0    1  148.0  1.0  1.0  2.0  NaN  NaN    1
# 14   62  1  4  120.0  220.0  0.0    1   86.0  0.0  0.0  NaN  NaN  NaN    0
# 15   63  1  4  170.0  177.0  0.0    0   84.0  1.0  2.5  3.0  NaN  NaN    4
# 16   46  1  4  110.0  236.0  0.0    0  125.0  1.0  2.0  2.0  NaN  NaN    1
# 17   63  1  4  126.0    0.0  0.0    1  120.0  0.0  1.5  3.0  NaN  NaN    0
# 18   60  1  4  152.0    0.0  0.0    1  118.0  1.0  0.0  NaN  NaN  7.0    0
# 19   58  1  4  116.0    0.0  0.0    0  124.0  0.0  1.0  1.0  NaN  NaN    2
# 20   64  1  4  120.0    0.0  1.0    1  106.0  0.0  2.0  2.0  NaN  NaN    1
# 21   63  1  3  130.0    0.0  0.0    1  111.0  1.0  0.0  NaN  NaN  NaN    3
# 22   74  1  3    NaN    0.0  0.0    0    NaN  NaN  NaN  NaN  NaN  NaN    0
# 23   52  1  3  128.0    0.0  0.0    1  180.0  0.0  3.0  1.0  NaN  NaN    2
# 24   69  1  4  130.0    0.0  1.0    1  129.0  0.0  1.0  2.0  NaN  6.0    2
# 25   51  1  4    NaN    0.0  1.0    1    NaN  NaN  NaN  NaN  NaN  NaN    2
# 26   60  1  4  130.0  186.0  1.0    1  140.0  1.0  0.5  2.0  NaN  NaN    1
# 27   56  1  4  120.0  100.0  0.0    0  120.0  1.0  1.5  2.0  0.0  7.0    1
# 28   55  1  3    NaN  228.0  0.0    1    NaN  NaN  NaN  NaN  NaN  NaN    3
# 29   54  1  4    NaN    0.0  0.0    1    NaN  NaN  NaN  NaN  NaN  NaN    3
# ..   .. .. ..    ...    ...  ...  ...    ...  ...  ...  ...  ...  ...  ...
# 169  53  1  4  124.0  243.0  0.0    0  122.0  1.0  2.0  2.0  NaN  7.0    1
# 170  37  1  3  118.0  240.0  0.0    2  165.0  0.0  1.0  2.0  NaN  3.0    0
# 171  67  1  4  140.0  219.0  0.0    1  122.0  1.0  2.0  2.0  NaN  7.0    3
# 172  74  1  3  140.0  237.0  1.0    0   94.0  0.0  0.0  NaN  NaN  NaN    1
# 173  63  1  2    NaN  165.0  0.0    1    NaN  NaN  NaN  NaN  NaN  NaN    0
# 174  58  1  4  100.0  213.0  0.0    1  110.0  0.0  0.0  NaN  NaN  NaN    0
# 175  61  1  4  190.0  287.0  1.0    2  150.0  1.0  2.0  3.0  NaN  NaN    4
# 176  64  1  4  130.0  258.0  1.0    2  130.0  0.0  0.0  NaN  NaN  6.0    2
# 177  58  1  4  160.0  256.0  1.0    2  113.0  1.0  1.0  1.0  NaN  NaN    3
# 178  60  1  4  130.0  186.0  1.0    2  140.0  1.0  0.5  2.0  NaN  NaN    1
# 179  57  1  4  122.0  264.0  0.0    2  100.0  0.0  0.0  NaN  NaN  NaN    1
# 180  55  1  3    NaN    NaN  0.0    1    NaN  NaN  NaN  NaN  NaN  NaN    0
# 181  55  1  4  120.0  226.0  0.0    2  127.0  1.0  1.7  3.0  NaN  7.0    1
# 182  56  1  4  130.0  203.0  1.0    0   98.0  0.0  1.5  2.0  NaN  7.0    1
# 183  57  1  4  130.0  207.0  0.0    1   96.0  1.0  1.0  2.0  NaN  NaN    0
# 184  61  1  3    NaN  284.0  0.0    0    NaN  NaN  NaN  NaN  NaN  NaN    1
# 185  61  1  3  120.0  337.0  0.0    0   98.0  1.0  0.0  NaN  NaN  NaN    3
# 186  58  1  3  150.0  219.0  0.0    1  118.0  1.0  0.0  NaN  NaN  NaN    2
# 187  74  1  4  155.0  310.0  0.0    0  112.0  1.0  1.5  3.0  NaN  NaN    2
# 188  68  1  3  134.0  254.0  1.0    0  151.0  1.0  0.0  NaN  NaN  3.0    0
# 189  51  0  4  114.0  258.0  1.0    2   96.0  0.0  1.0  1.0  NaN  NaN    0
# 190  62  1  4  160.0  254.0  1.0    1  108.0  1.0  3.0  2.0  NaN  NaN    4
# 191  53  1  4  144.0  300.0  1.0    1  128.0  1.0  1.5  2.0  NaN  NaN    3
# 192  62  1  4  158.0  170.0  0.0    1  138.0  1.0  0.0  NaN  NaN  NaN    1
# 193  46  1  4  134.0  310.0  0.0    0  126.0  0.0  0.0  NaN  NaN  3.0    2
# 194  54  0  4  127.0  333.0  1.0    1  154.0  0.0  0.0  NaN  NaN  NaN    1
# 195  62  1  1    NaN  139.0  0.0    1    NaN  NaN  NaN  NaN  NaN  NaN    0
# 196  55  1  4  122.0  223.0  1.0    1  100.0  0.0  0.0  NaN  NaN  6.0    2
# 197  58  1  4    NaN  385.0  1.0    2    NaN  NaN  NaN  NaN  NaN  NaN    0
# 198  62  1  2  120.0  254.0  0.0    2   93.0  1.0  0.0  NaN  NaN  NaN    1
#
# [199 rows x 14 columns]

# %%
ds=ds.rename(columns={"63":"age","1":"sex","4":"cp","140":"trestbps","260":"chol","0":"fbs","1.1":"restecg","112":"thalach","1.2":"exang","3":"oldpeak","2":"slope","?":"ca","?.1":"thal","2.1":"num"})
ds
# Out:
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     44    1   4     130.0  209.0  0.0        1    127.0    0.0      0.0
# 1     60    1   4     132.0  218.0  0.0        1    140.0    1.0      1.5
# 2     55    1   4     142.0  228.0  0.0        1    149.0    1.0      2.5
# 3     66    1   3     110.0  213.0  1.0        2     99.0    1.0      1.3
# 4     66    1   3     120.0    0.0  0.0        1    120.0    0.0     -0.5
# 5     65    1   4     150.0  236.0  1.0        1    105.0    1.0      0.0
# 6     60    1   3     180.0    0.0  0.0        1    140.0    1.0      1.5
# 7     60    1   3     120.0    0.0  NaN        0    141.0    1.0      2.0
# 8     60    1   2     160.0  267.0  1.0        1    157.0    0.0      0.5
# 9     56    1   2     126.0  166.0  0.0        1    140.0    0.0      0.0
# 10    59    1   4     140.0    0.0  0.0        1    117.0    1.0      1.0
# 11    62    1   4     110.0    0.0  0.0        0    120.0    1.0      0.5
# 12    63    1   3       NaN    0.0  0.0        2      NaN    NaN      NaN
# 13    57    1   4     128.0    0.0  1.0        1    148.0    1.0      1.0
# 14    62    1   4     120.0  220.0  0.0        1     86.0    0.0      0.0
# 15    63    1   4     170.0  177.0  0.0        0     84.0    1.0      2.5
# 16    46    1   4     110.0  236.0  0.0        0    125.0    1.0      2.0
# 17    63    1   4     126.0    0.0  0.0        1    120.0    0.0      1.5
# 18    60    1   4     152.0    0.0  0.0        1    118.0    1.0      0.0
# 19    58    1   4     116.0    0.0  0.0        0    124.0    0.0      1.0
# 20    64    1   4     120.0    0.0  1.0        1    106.0    0.0      2.0
# 21    63    1   3     130.0    0.0  0.0        1    111.0    1.0      0.0
# 22    74    1   3       NaN    0.0  0.0        0      NaN    NaN      NaN
# 23    52    1   3     128.0    0.0  0.0        1    180.0    0.0      3.0
# 24    69    1   4     130.0    0.0  1.0        1    129.0    0.0      1.0
# 25    51    1   4       NaN    0.0  1.0        1      NaN    NaN      NaN
# 26    60    1   4     130.0  186.0  1.0        1    140.0    1.0      0.5
# 27    56    1   4     120.0  100.0  0.0        0    120.0    1.0      1.5
# 28    55    1   3       NaN  228.0  0.0        1      NaN    NaN      NaN
# 29    54    1   4       NaN    0.0  0.0        1      NaN    NaN      NaN
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 169   53    1   4     124.0  243.0  0.0        0    122.0    1.0      2.0
# 170   37    1   3     118.0  240.0  0.0        2    165.0    0.0      1.0
# 171   67    1   4     140.0  219.0  0.0        1    122.0    1.0      2.0
# 172   74    1   3     140.0  237.0  1.0        0     94.0    0.0      0.0
# 173   63    1   2       NaN  165.0  0.0        1      NaN    NaN      NaN
# 174   58    1   4     100.0  213.0  0.0        1    110.0    0.0      0.0
# 175   61    1   4     190.0  287.0  1.0        2    150.0    1.0      2.0
# 176   64    1   4     130.0  258.0  1.0        2    130.0    0.0      0.0
# 177   58    1   4     160.0  256.0  1.0        2    113.0    1.0      1.0
# 178   60    1   4     130.0  186.0  1.0        2    140.0    1.0      0.5
# 179   57    1   4     122.0  264.0  0.0        2    100.0    0.0      0.0
# 180   55    1   3       NaN    NaN  0.0        1      NaN    NaN      NaN
# 181   55    1   4     120.0  226.0  0.0        2    127.0    1.0      1.7
# 182   56    1   4     130.0  203.0  1.0        0     98.0    0.0      1.5
# 183   57    1   4     130.0  207.0  0.0        1     96.0    1.0      1.0
# 184   61    1   3       NaN  284.0  0.0        0      NaN    NaN      NaN
# 185   61    1   3     120.0  337.0  0.0        0     98.0    1.0      0.0
# 186   58    1   3     150.0  219.0  0.0        1    118.0    1.0      0.0
# 187   74    1   4     155.0  310.0  0.0        0    112.0    1.0      1.5
# 188   68    1   3     134.0  254.0  1.0        0    151.0    1.0      0.0
# 189   51    0   4     114.0  258.0  1.0        2     96.0    0.0      1.0
# 190   62    1   4     160.0  254.0  1.0        1    108.0    1.0      3.0
# 191   53    1   4     144.0  300.0  1.0        1    128.0    1.0      1.5
# 192   62    1   4     158.0  170.0  0.0        1    138.0    1.0      0.0
# 193   46    1   4     134.0  310.0  0.0        0    126.0    0.0      0.0
# 194   54    0   4     127.0  333.0  1.0        1    154.0    0.0      0.0
# 195   62    1   1       NaN  139.0  0.0        1      NaN    NaN      NaN
# 196   55    1   4     122.0  223.0  1.0        1    100.0    0.0      0.0
# 197   58    1   4       NaN  385.0  1.0        2      NaN    NaN      NaN
# 198   62    1   2     120.0  254.0  0.0        2     93.0    1.0      0.0
#
#      slope   ca  thal  num
# 0      NaN  NaN   NaN    0
# 1      3.0  NaN   NaN    2
# 2      1.0  NaN   NaN    1
# 3      2.0  NaN   NaN    0
# 4      1.0  NaN   NaN    0
# 5      NaN  NaN   NaN    3
# 6      2.0  NaN   NaN    0
# 7      1.0  NaN   NaN    3
# 8      2.0  NaN   NaN    1
# 9      NaN  NaN   NaN    0
# 10     2.0  NaN   NaN    1
# 11     2.0  NaN   3.0    1
# 12     NaN  NaN   NaN    1
# 13     2.0  NaN   NaN    1
# 14     NaN  NaN   NaN    0
# 15     3.0  NaN   NaN    4
# 16     2.0  NaN   NaN    1
# 17     3.0  NaN   NaN    0
# 18     NaN  NaN   7.0    0
# 19     1.0  NaN   NaN    2
# 20     2.0  NaN   NaN    1
# 21     NaN  NaN   NaN    3
# 22     NaN  NaN   NaN    0
# 23     1.0  NaN   NaN    2
# 24     2.0  NaN   6.0    2
# 25     NaN  NaN   NaN    2
# 26     2.0  NaN   NaN    1
# 27     2.0  0.0   7.0    1
# 28     NaN  NaN   NaN    3
# 29     NaN  NaN   NaN    3
# ..     ...  ...   ...  ...
# 169    2.0  NaN   7.0    1
# 170    2.0  NaN   3.0    0
# 171    2.0  NaN   7.0    3
# 172    NaN  NaN   NaN    1
# 173    NaN  NaN   NaN    0
# 174    NaN  NaN   NaN    0
# 175    3.0  NaN   NaN    4
# 176    NaN  NaN   6.0    2
# 177    1.0  NaN   NaN    3
# 178    2.0  NaN   NaN    1
# 179    NaN  NaN   NaN    1
# 180    NaN  NaN   NaN    0
# 181    3.0  NaN   7.0    1
# 182    2.0  NaN   7.0    1
# 183    2.0  NaN   NaN    0
# 184    NaN  NaN   NaN    1
# 185    NaN  NaN   NaN    3
# 186    NaN  NaN   NaN    2
# 187    3.0  NaN   NaN    2
# 188    NaN  NaN   3.0    0
# 189    1.0  NaN   NaN    0
# 190    2.0  NaN   NaN    4
# 191    2.0  NaN   NaN    3
# 192    NaN  NaN   NaN    1
# 193    NaN  NaN   3.0    2
# 194    NaN  NaN   NaN    1
# 195    NaN  NaN   NaN    0
# 196    NaN  NaN   6.0    2
# 197    NaN  NaN   NaN    0
# 198    NaN  NaN   NaN    1
#
# [199 rows x 14 columns]

# %%
ds.isnull().sum()
# Out:
# age           0
# sex           0
# cp            0
# trestbps     56
# chol          7
# fbs           7
# restecg       0
# thalach      53
# exang        53
# oldpeak      56
# slope       102
# ca          197
# thal        165
# num           0
# dtype: int64

# %%
ds.nunique()
# Out:
# age         39
# sex          2
# cp           4
# trestbps    40
# chol        99
# fbs          2
# restecg      3
# thalach     59
# exang        2
# oldpeak     14
# slope        3
# ca           1
# thal         3
# num          5
# dtype: int64

# %%
ds['ca'].unique()
# Out:
# array([nan,  0.])

# %%
ds['slope'].unique()
# Out:
# array([nan,  3.,  1.,  2.])

# %%
ds['thal'].unique()
# Out:
# array([nan,  3.,  7.,  6.])

# %%
ds['exang'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
ds['fbs'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
ds['num'].unique()
# Out:
# array([0, 2, 1, 3, 4], dtype=int64)

# %%
ds.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  199.000000  199.000000  199.000000  143.000000  192.000000  192.000000
# mean    59.331658    0.969849    3.502513  133.720280  178.322917    0.354167
# std      7.827080    0.171433    0.796928   21.607056  114.181310    0.479510
# min     35.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%     55.000000    1.000000    3.000000  120.000000    0.000000    0.000000
# 50%     60.000000    1.000000    4.000000  130.000000  216.000000    0.000000
# 75%     64.000000    1.000000    4.000000  148.000000  256.500000    1.000000
# max     77.000000    1.000000    4.000000  190.000000  458.000000    1.000000
#
#           restecg     thalach       exang     oldpeak      slope   ca  \
# count  199.000000  146.000000  146.000000  143.000000  97.000000  2.0
# mean     0.733668  122.869863    0.643836    1.309091   2.134021  0.0
# std      0.684918   22.047680    0.480513    1.101082   0.671268  0.0
# min      0.000000   69.000000    0.000000   -0.500000   1.000000  0.0
# 25%      0.000000  108.500000    0.000000    0.000000   2.000000  0.0
# 50%      1.000000  120.000000    1.000000    1.500000   2.000000  0.0
# 75%      1.000000  140.000000    1.000000    2.000000   3.000000  0.0
# max      2.000000  180.000000    1.000000    4.000000   3.000000  0.0
#
#             thal         num
# count  34.000000  199.000000
# mean    6.294118    1.517588
# std     1.291685    1.222038
# min     3.000000    0.000000
# 25%     6.000000    0.000000
# 50%     7.000000    1.000000
# 75%     7.000000    3.000000
# max     7.000000    4.000000

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 14 columns):
# age         199 non-null int64
# sex         199 non-null int64
# cp          199 non-null int64
# trestbps    143 non-null float64
# chol        192 non-null float64
# fbs         192 non-null float64
# restecg     199 non-null int64
# thalach     146 non-null float64
# exang       146 non-null float64
# oldpeak     143 non-null float64
# slope       97 non-null float64
# ca          2 non-null float64
# thal        34 non-null float64
# num         199 non-null int64
# dtypes: float64(9), int64(5)
# memory usage: 21.8 KB

# %%
ds
# Out:
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     44    1   4     130.0  209.0  0.0        1    127.0    0.0      0.0
# 1     60    1   4     132.0  218.0  0.0        1    140.0    1.0      1.5
# 2     55    1   4     142.0  228.0  0.0        1    149.0    1.0      2.5
# 3     66    1   3     110.0  213.0  1.0        2     99.0    1.0      1.3
# 4     66    1   3     120.0    0.0  0.0        1    120.0    0.0     -0.5
# 5     65    1   4     150.0  236.0  1.0        1    105.0    1.0      0.0
# 6     60    1   3     180.0    0.0  0.0        1    140.0    1.0      1.5
# 7     60    1   3     120.0    0.0  NaN        0    141.0    1.0      2.0
# 8     60    1   2     160.0  267.0  1.0        1    157.0    0.0      0.5
# 9     56    1   2     126.0  166.0  0.0        1    140.0    0.0      0.0
# 10    59    1   4     140.0    0.0  0.0        1    117.0    1.0      1.0
# 11    62    1   4     110.0    0.0  0.0        0    120.0    1.0      0.5
# 12    63    1   3       NaN    0.0  0.0        2      NaN    NaN      NaN
# 13    57    1   4     128.0    0.0  1.0        1    148.0    1.0      1.0
# 14    62    1   4     120.0  220.0  0.0        1     86.0    0.0      0.0
# 15    63    1   4     170.0  177.0  0.0        0     84.0    1.0      2.5
# 16    46    1   4     110.0  236.0  0.0        0    125.0    1.0      2.0
# 17    63    1   4     126.0    0.0  0.0        1    120.0    0.0      1.5
# 18    60    1   4     152.0    0.0  0.0        1    118.0    1.0      0.0
# 19    58    1   4     116.0    0.0  0.0        0    124.0    0.0      1.0
# 20    64    1   4     120.0    0.0  1.0        1    106.0    0.0      2.0
# 21    63    1   3     130.0    0.0  0.0        1    111.0    1.0      0.0
# 22    74    1   3       NaN    0.0  0.0        0      NaN    NaN      NaN
# 23    52    1   3     128.0    0.0  0.0        1    180.0    0.0      3.0
# 24    69    1   4     130.0    0.0  1.0        1    129.0    0.0      1.0
# 25    51    1   4       NaN    0.0  1.0        1      NaN    NaN      NaN
# 26    60    1   4     130.0  186.0  1.0        1    140.0    1.0      0.5
# 27    56    1   4     120.0  100.0  0.0        0    120.0    1.0      1.5
# 28    55    1   3       NaN  228.0  0.0        1      NaN    NaN      NaN
# 29    54    1   4       NaN    0.0  0.0        1      NaN    NaN      NaN
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 169   53    1   4     124.0  243.0  0.0        0    122.0    1.0      2.0
# 170   37    1   3     118.0  240.0  0.0        2    165.0    0.0      1.0
# 171   67    1   4     140.0  219.0  0.0        1    122.0    1.0      2.0
# 172   74    1   3     140.0  237.0  1.0        0     94.0    0.0      0.0
# 173   63    1   2       NaN  165.0  0.0        1      NaN    NaN      NaN
# 174   58    1   4     100.0  213.0  0.0        1    110.0    0.0      0.0
# 175   61    1   4     190.0  287.0  1.0        2    150.0    1.0      2.0
# 176   64    1   4     130.0  258.0  1.0        2    130.0    0.0      0.0
# 177   58    1   4     160.0  256.0  1.0        2    113.0    1.0      1.0
# 178   60    1   4     130.0  186.0  1.0        2    140.0    1.0      0.5
# 179   57    1   4     122.0  264.0  0.0        2    100.0    0.0      0.0
# 180   55    1   3       NaN    NaN  0.0        1      NaN    NaN      NaN
# 181   55    1   4     120.0  226.0  0.0        2    127.0    1.0      1.7
# 182   56    1   4     130.0  203.0  1.0        0     98.0    0.0      1.5
# 183   57    1   4     130.0  207.0  0.0        1     96.0    1.0      1.0
# 184   61    1   3       NaN  284.0  0.0        0      NaN    NaN      NaN
# 185   61    1   3     120.0  337.0  0.0        0     98.0    1.0      0.0
# 186   58    1   3     150.0  219.0  0.0        1    118.0    1.0      0.0
# 187   74    1   4     155.0  310.0  0.0        0    112.0    1.0      1.5
# 188   68    1   3     134.0  254.0  1.0        0    151.0    1.0      0.0
# 189   51    0   4     114.0  258.0  1.0        2     96.0    0.0      1.0
# 190   62    1   4     160.0  254.0  1.0        1    108.0    1.0      3.0
# 191   53    1   4     144.0  300.0  1.0        1    128.0    1.0      1.5
# 192   62    1   4     158.0  170.0  0.0        1    138.0    1.0      0.0
# 193   46    1   4     134.0  310.0  0.0        0    126.0    0.0      0.0
# 194   54    0   4     127.0  333.0  1.0        1    154.0    0.0      0.0
# 195   62    1   1       NaN  139.0  0.0        1      NaN    NaN      NaN
# 196   55    1   4     122.0  223.0  1.0        1    100.0    0.0      0.0
# 197   58    1   4       NaN  385.0  1.0        2      NaN    NaN      NaN
# 198   62    1   2     120.0  254.0  0.0        2     93.0    1.0      0.0
#
#      slope   ca  thal  num
# 0      NaN  NaN   NaN    0
# 1      3.0  NaN   NaN    2
# 2      1.0  NaN   NaN    1
# 3      2.0  NaN   NaN    0
# 4      1.0  NaN   NaN    0
# 5      NaN  NaN   NaN    3
# 6      2.0  NaN   NaN    0
# 7      1.0  NaN   NaN    3
# 8      2.0  NaN   NaN    1
# 9      NaN  NaN   NaN    0
# 10     2.0  NaN   NaN    1
# 11     2.0  NaN   3.0    1
# 12     NaN  NaN   NaN    1
# 13     2.0  NaN   NaN    1
# 14     NaN  NaN   NaN    0
# 15     3.0  NaN   NaN    4
# 16     2.0  NaN   NaN    1
# 17     3.0  NaN   NaN    0
# 18     NaN  NaN   7.0    0
# 19     1.0  NaN   NaN    2
# 20     2.0  NaN   NaN    1
# 21     NaN  NaN   NaN    3
# 22     NaN  NaN   NaN    0
# 23     1.0  NaN   NaN    2
# 24     2.0  NaN   6.0    2
# 25     NaN  NaN   NaN    2
# 26     2.0  NaN   NaN    1
# 27     2.0  0.0   7.0    1
# 28     NaN  NaN   NaN    3
# 29     NaN  NaN   NaN    3
# ..     ...  ...   ...  ...
# 169    2.0  NaN   7.0    1
# 170    2.0  NaN   3.0    0
# 171    2.0  NaN   7.0    3
# 172    NaN  NaN   NaN    1
# 173    NaN  NaN   NaN    0
# 174    NaN  NaN   NaN    0
# 175    3.0  NaN   NaN    4
# 176    NaN  NaN   6.0    2
# 177    1.0  NaN   NaN    3
# 178    2.0  NaN   NaN    1
# 179    NaN  NaN   NaN    1
# 180    NaN  NaN   NaN    0
# 181    3.0  NaN   7.0    1
# 182    2.0  NaN   7.0    1
# 183    2.0  NaN   NaN    0
# 184    NaN  NaN   NaN    1
# 185    NaN  NaN   NaN    3
# 186    NaN  NaN   NaN    2
# 187    3.0  NaN   NaN    2
# 188    NaN  NaN   3.0    0
# 189    1.0  NaN   NaN    0
# 190    2.0  NaN   NaN    4
# 191    2.0  NaN   NaN    3
# 192    NaN  NaN   NaN    1
# 193    NaN  NaN   3.0    2
# 194    NaN  NaN   NaN    1
# 195    NaN  NaN   NaN    0
# 196    NaN  NaN   6.0    2
# 197    NaN  NaN   NaN    0
# 198    NaN  NaN   NaN    1
#
# [199 rows x 14 columns]

# %%
ds['slope'].fillna(ds['slope'].mode()[0], inplace = True)

# %%
ds['oldpeak'].fillna(ds['oldpeak'].median(), inplace = True)

# %%
ds['trestbps'].fillna(ds['trestbps'].median(), inplace = True)

# %%
ds['chol'].fillna(ds['chol'].median(), inplace = True)

# %%
ds['thalach'].fillna(ds['thalach'].median(), inplace = True)

# %%
ds['fbs'].fillna(ds['fbs'].mode()[0], inplace = True)

# %%
ds['exang'].fillna(ds['exang'].mode()[0], inplace = True)

# %%
ds['slope'].fillna(ds['slope'].mode()[0], inplace = True)

# %%
#Removing ca column since null values are more than 50%
ds.drop('ca',axis=1,inplace=True)

# %%
#Removing thal column since null values are more than 50%
ds.drop('thal',axis=1,inplace=True)

# %%
#Removing thal column since null values are more than 50%
ds.drop('chol',axis=1,inplace=True)

# %%
#Removing thal column since null values are more than 50%
ds.drop('fbs',axis=1,inplace=True)

# %%
#Removing thal column since null values are more than 50%
ds.drop('restecg',axis=1,inplace=True)

# %%
corr=ds.corr()
plt.figure(figsize=(16,5))
sn.heatmap(corr,annot=True,linewidths=.8)
plt.show()

# %%
ds.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# num         0
# dtype: int64

# %%
sn.boxplot(data=ds['exang'])
plt.show()

# %%
sn.boxplot(data=ds['oldpeak'])
plt.show()

# %%
sn.boxplot(data=ds['thalach'])
plt.show()

# %%
sn.boxplot(data=ds['trestbps'])
plt.show()

# %%
from scipy.stats import skew

# %%
for col in ds:
    print(col)
    print(skew(ds[col]))
    
    plt.figure()
    sn.distplot(ds[col])
    plt.show()
# Out:
# age
# -0.3941778516165176
# sex
# -5.495248379242576
# cp
# -1.628870017473588
# trestbps
# -1.3028292209281285
# thalach
# 0.2563239832060294
# exang
# -1.086583900820234
# oldpeak
# 0.2620300384439067
# slope
# 0.20637877702158003
# num
# 0.30039468191713364

# %%
ds_n=ds

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(ds_n))
print(z)

threshold = 3
print(np.where(z > 3))

ds_n = ds_n[(z < 3).all(axis=1)]
# Out:
# [[1.96373685 0.17631813 0.62583065 ... 1.45900654 0.13869083 1.24498245]
#  [0.08560374 0.17631813 0.62583065 ... 0.14686902 1.98434575 0.39575601]
#  [0.5548152  0.17631813 0.62583065 ... 1.21745273 2.26172741 0.42461322]
#  ...
#  [0.5548152  0.17631813 0.62583065 ... 1.45900654 0.13869083 0.39575601]
#  [0.17056384 0.17631813 0.62583065 ... 0.14686902 0.13869083 1.24498245]
#  [0.34177131 0.17631813 1.89013499 ... 1.45900654 0.13869083 0.42461322]]
# (array([ 23,  32,  50,  65,  69,  71,  75,  78,  95,  96, 125, 127, 130,
#        132, 136, 175, 189, 194, 195], dtype=int64), array([4, 3, 1, 2, 4, 2, 2, 1, 0, 2, 1, 1, 2, 2, 2, 3, 1, 1, 2],
#       dtype=int64))

# %%
ds.shape
# Out:
# (199, 9)

# %%
ds_n.shape
# Out:
# (180, 9)

# %%
#creating target variable and seperating data into X and Y
x=ds_n.drop("num",axis=1)
y=ds_n['num']

# %% [markdown]
# #Scling data using standardscalar method
# from sklearn.preprocessing import StandardScaler
# sc=StandardScaler()
# scaledx=sc.fit_transform(x)

# %%
#
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25)

# %%
#Since the Preprocessing and EDA is done we can build our model using Different Algorithms
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)

y_pred=lr.predict(x_test)
y_pred

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.30      0.43      0.35         7
#            1       0.32      0.64      0.42        11
#            2       0.40      0.18      0.25        11
#            3       0.50      0.29      0.36        14
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.36        45
#    macro avg       0.30      0.31      0.28        45
# weighted avg       0.38      0.36      0.33        45
#
# Accuracy: 0.35555555555555557
# C:\Users\ajay\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\ajay\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\ajay\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestClassifier
rd=RandomForestClassifier(n_estimators=100)
rd.fit(x_train,y_train)
y_pred=rd.predict(x_test)

print(classification_report(y_test, y_pred))

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.25      0.57      0.35         7
#            1       0.19      0.27      0.22        11
#            2       0.14      0.09      0.11        11
#            3       0.50      0.21      0.30        14
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.24        45
#    macro avg       0.22      0.23      0.20        45
# weighted avg       0.28      0.24      0.23        45
#
# Accuracy: 0.24444444444444444
# C:\Users\ajay\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from sklearn.svm import SVC   
classifier = SVC(kernel='linear')  

classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(x_train, y_train)

y_pred = classifier.predict(x_test)


print(classification_report(y_test, y_pred))
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.27      0.43      0.33         7
#            1       0.32      0.55      0.40        11
#            2       0.12      0.09      0.11        11
#            3       0.50      0.21      0.30        14
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.29        45
#    macro avg       0.24      0.26      0.23        45
# weighted avg       0.31      0.29      0.27        45
#
# Accuracy: 0.28888888888888886

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(x_train, y_train)

y_pred = classifier.predict(x_test)


print(classification_report(y_test, y_pred))
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.43      0.43      0.43         7
#            1       0.33      0.18      0.24        11
#            2       0.00      0.00      0.00        11
#            3       0.50      0.07      0.12        14
#            4       0.03      0.50      0.06         2
#
#     accuracy                           0.16        45
#    macro avg       0.26      0.24      0.17        45
# weighted avg       0.31      0.16      0.17        45
#
# Accuracy: 0.15555555555555556
# C:\Users\ajay\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
#We will try to improve performance of our best model using GridSearchCV
from sklearn.model_selection import GridSearchCV 
# Parameter GridSearchCV 
search_param = {
    "n_estimators": [100],
    "criterion": ["gini", "entropy"],
    'max_features': [0.5, 1.0, "sqrt"],
    'max_depth': [4, 5, 6, 7, 8, None],
}



#Hyper tunning Random Forest
forest = RandomForestClassifier(random_state = 0)
grid   = GridSearchCV(forest, search_param, cv = 12, verbose = 0)
grid.fit(x_train, y_train)


y_pred = classifier.predict(x_test)

print(" Best Score :",grid.best_score_)
print(" Best Params :",grid.best_params_)

 
predictions = grid.predict(x_test)
print(classification_report(y_test, predictions))


# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# C:\Users\ajay\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:657: Warning: The least populated class in y has only 7 members, which is too few. The minimum number of members in any class cannot be less than n_splits=12.
#   % (min_groups, self.n_splits)), Warning)
# C:\Users\ajay\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
#  Best Score : 0.34814814814814815
#  Best Params : {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.20      0.43      0.27         7
#            1       0.22      0.36      0.28        11
#            2       0.20      0.09      0.13        11
#            3       0.57      0.29      0.38        14
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.27        45
#    macro avg       0.24      0.23      0.21        45
# weighted avg       0.31      0.27      0.26        45
#
# Accuracy: 0.15555555555555556
# C:\Users\ajay\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
#saving our best model
import pickle
filename = 'Heartdisease.pkl'
pickle.dump(classifier,open(filename, 'wb'))
