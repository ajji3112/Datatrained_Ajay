# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
ds=pd.read_csv("E:/Datatrained/Practise_Project/happiness_score/happiness_score.csv")

# %%
ds.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
# Country                          158 non-null object
# Region                           158 non-null object
# Happiness Rank                   158 non-null int64
# Happiness Score                  158 non-null float64
# Standard Error                   158 non-null float64
# Economy (GDP per Capita)         158 non-null float64
# Family                           158 non-null float64
# Health (Life Expectancy)         158 non-null float64
# Freedom                          158 non-null float64
# Trust (Government Corruption)    158 non-null float64
# Generosity                       158 non-null float64
# Dystopia Residual                158 non-null float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
ds.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
ds.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
ds.Region=le.fit_transform(ds.Region)
ds.Country=le.fit_transform(ds.Country)

# %%
ds
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# 5         45       9               6            7.406         0.03140
# 6         99       9               7            7.378         0.02799
# 7        134       9               8            7.364         0.03157
# 8        100       0               9            7.286         0.03371
# 9          6       0              10            7.284         0.04083
# 10        64       4              11            7.278         0.03470
# 11        33       3              12            7.226         0.04454
# ...

# %%
corr=ds.corr()
sn.heatmap(corr,annot=True)
plt.show()

# %%
ds.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
sn.boxplot(data=ds[["Standard Error"]],orient="h",palette="Set2")
plt.show()

# %%
sn.boxplot(data=ds[["Standard Error"]])
plt.show()

# %%
sn.boxplot(data=ds[["Economy (GDP per Capita)"]])
plt.show()

# %%
sn.boxplot(data=ds[["Family"]])
plt.show()

# %%
sn.boxplot(data=ds[["Health (Life Expectancy)"]])
plt.show()

# %%
sn.boxplot(data=ds[["Freedom"]])
plt.show()

# %%
sn.boxplot(data=ds[["Trust (Government Corruption)"]])
plt.show()

# %%
sn.boxplot(data=ds[["Generosity"]])
plt.show()

# %%
sn.boxplot(data=ds[["Dystopia Residual"]])
plt.show()

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
# Country                          158 non-null int32
# Region                           158 non-null int32
# Happiness Rank                   158 non-null int64
# Happiness Score                  158 non-null float64
# Standard Error                   158 non-null float64
# Economy (GDP per Capita)         158 non-null float64
# Family                           158 non-null float64
# Health (Life Expectancy)         158 non-null float64
# Freedom                          158 non-null float64
# Trust (Government Corruption)    158 non-null float64
# Generosity                       158 non-null float64
# Dystopia Residual                158 non-null float64
# dtypes: float64(9), int32(2), int64(1)
# memory usage: 13.7 KB

# %%
#ds_Country = pd.get_dummies(ds['Country'], prefix='Serial_', drop_first = True)
#ds_Region = pd.get_dummies(ds['Region'], drop_first = True)
#ds = pd.concat([ds,ds_Region], axis = 1)
#df.drop(['Country','Region'], inplace = True, axis = 1)

# %%
from scipy.stats import zscore
z=np.abs(zscore(ds_new))
threshold=3
ds_new1=ds_new[(z<3).all(axis=1)]

# %%
ds_new1
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# 5                 6            7.406         0.03140
# 6                 7            7.378         0.02799
# 7                 8            7.364         0.03157
# 8                 9            7.286         0.03371
# 9                10            7.284         0.04083
# 10               11            7.278         0.03470
# 11               12            7.226         0.04454
# 12               13            7.200         0.03751
# 13               14            7.187         0.04176
# 14               15            7.119         0.03839
# 15               16            6.983         0.04076
# 16               17            6.946         0.03499
# ...

# %%
ds_new1.shape
# Out:
# (149, 10)

# %%
x=ds_new1.drop("Happiness Score",axis=1)
y=ds_new1["Happiness Score"]

# %%
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
# 5      7.406
# 6      7.378
# 7      7.364
# 8      7.286
# 9      7.284
# 10     7.278
# 11     7.226
# 12     7.200
# 13     7.187
# 14     7.119
# 15     6.983
# 16     6.946
# 17     6.940
# 18     6.937
# 19     6.901
# 20     6.867
# 21     6.853
# 22     6.810
# 23     6.798
# 24     6.786
# 25     6.750
# 26     6.670
# 28     6.575
# 29     6.574
# 30     6.505
#        ...
# 123    4.436
# 124    4.419
# 125    4.369
# 126    4.350
# 127    4.332
# 129    4.297
# 130    4.292
# 131    4.271
# 132    4.252
# 133    4.218
# 134    4.194
# 135    4.077
# 136    4.033
# 137    3.995
# 138    3.989
# 139    3.956
# 140    3.931
# 141    3.904
# 142    3.896
# 143    3.845
# 144    3.819
# 145    3.781
# 146    3.681
# 148    3.667
# 149    3.656
# 150    3.655
# 151    3.587
# 152    3.575
# 154    3.340
# 156    2.905
# Name: Happiness Score, Length: 149, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = .25)

# %%
#from sklearn.preprocessing import StandardScaler
#sc=StandardScaler()
#scaledx=sc.fit_transform(x)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score

best_rstate=0
accu=0

for i in range(20,300):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=i)
    mod=LinearRegression()
    mod.fit(x_train,y_train)
    y_pred=mod.predict(x_test)
    tempaccu=r2_score(y_pred,y_test)
    if tempaccu>accu:
        accu=tempaccu
        best_rstate=i
        
print(f"best accuracy {accu*100} found on randome_state {best_rstate}")
# Out:
# best accuracy 99.99999596600875 found on randome_state 117

# %%
score=mod.score(x_test,y_test)
score
# Out:
# 0.9999999426251928

# %%
score=mod.score(x_train,y_train)
score
# Out:
# 0.9999999346544437

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor
rd=RandomForestRegressor()
rd.fit(x_test,y_test)
y_pred=rd.predict(x_test)
r2score=r2_score(y_test,y_pred)
print(f"Accuracu is {r2score*100}")
# Out:
# Accuracu is 99.07551419949993
# C:\Users\ajay\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
