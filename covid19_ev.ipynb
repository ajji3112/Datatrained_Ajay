# %%
#importing libraries
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
#Reading our dataset
ds=pd.read_csv("E:/Datatrained/Evaluation/evaluation/tnt.csv")
ds
# Out:
#             Date                 Country  Population  Total Tests  \
# 0     2020-04-18                     USA   330774664    3722145.0
# 1     2020-04-18                  Russia   145927292    1831892.0
# 2     2020-04-18                   Spain    46752703     930230.0
# 3     2020-04-18                  Brazil   212380932      62985.0
# 4     2020-04-18                      UK    67844241     460437.0
# 5     2020-04-18                   Italy    60471924    1305833.0
# 6     2020-04-18                  France    65256826     463662.0
# 7     2020-04-18                 Germany    83752855    1728357.0
# 8     2020-04-18                  Turkey    84230075     598933.0
# 9     2020-04-18                    Iran    83862642     330137.0
# 10    2020-04-18                   India  1378381772     335123.0
# 11    2020-04-18                    Peru    32915899     135895.0
# 12    2020-04-18                   China  1439323776          NaN
# ...

# %%
#checking the columns and datatype of each column
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6603 entries, 0 to 6602
# Data columns (total 9 columns):
# Date                   6603 non-null object
# Country                6603 non-null object
# Population             6603 non-null int64
# Total Tests            5505 non-null float64
# Total Cases            6554 non-null float64
# Total Deaths           5367 non-null float64
# Total Recovered        6318 non-null float64
# Serious or Critical    4117 non-null float64
# Active Cases           6544 non-null float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 464.4+ KB

# %%
ds.isnull().sum()
# Out:
# Date                      0
# Country                   0
# Population                0
# Total Tests            1098
# Total Cases              49
# Total Deaths           1236
# Total Recovered         285
# Serious or Critical    2486
# Active Cases             59
# dtype: int64

# %% [markdown]
# We can observer there are null values in
# Total Tests,Total cases,Total deaths,Total recovered,Serious critical and Active cases

# %%
ds.head()
# Out:
#          Date Country  Population  Total Tests  Total Cases  Total Deaths  \
# 0  2020-04-18     USA   330774664    3722145.0     738792.0       39014.0
# 1  2020-04-18  Russia   145927292    1831892.0      36793.0         313.0
# 2  2020-04-18   Spain    46752703     930230.0     194416.0       20043.0
# 3  2020-04-18  Brazil   212380932      62985.0      36722.0        2361.0
# 4  2020-04-18      UK    67844241     460437.0     114217.0       15464.0
#
#    Total Recovered  Serious or Critical  Active Cases
# 0          68269.0              13551.0      631509.0
# 1           3057.0                  8.0       33423.0
# 2          74797.0               7371.0       99576.0
# 3          14026.0               6634.0       20335.0
# 4              NaN               1559.0       98409.0

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6603 entries, 0 to 6602
# Data columns (total 9 columns):
# Date                   6603 non-null object
# Country                6603 non-null object
# Population             6603 non-null int64
# Total Tests            5505 non-null float64
# Total Cases            6554 non-null float64
# Total Deaths           5367 non-null float64
# Total Recovered        6318 non-null float64
# Serious or Critical    4117 non-null float64
# Active Cases           6544 non-null float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 464.4+ KB

# %%
#We can check the mean,medium and get an idea about data skewness
ds.describe()
# Out:
#          Population   Total Tests   Total Cases  Total Deaths  \
# count  6.603000e+03  5.505000e+03  6.554000e+03   5367.000000
# mean   3.637913e+07  2.167252e+05  1.692968e+04   1416.252096
# std    1.411537e+08  7.595143e+05  8.861467e+04   6645.247810
# min    8.010000e+02  1.000000e+01  1.000000e+00      0.000000
# 25%    8.672680e+05  2.690000e+03  7.900000e+01      6.000000
# 50%    6.859926e+06  2.547800e+04  6.135000e+02     24.000000
# 75%    2.546422e+07  1.437810e+05  4.877500e+03    199.000000
# max    1.439324e+09  1.230074e+07  1.550294e+06  91981.000000
#
#        Total Recovered  Serious or Critical  Active Cases
# count      6318.000000          4117.000000  6.544000e+03
# mean       5855.424185           386.748360  9.964142e+03
# std       23467.641235          1658.428324  6.541025e+04
# min           1.000000             1.000000  0.000000e+00
# 25%          26.000000             3.000000  2.600000e+01
# ...

# %%
ds.isnull().sum()
# Out:
# Date                      0
# Country                   0
# Population                0
# Total Tests            1098
# Total Cases              49
# Total Deaths           1236
# Total Recovered         285
# Serious or Critical    2486
# Active Cases             59
# dtype: int64

# %%
ds.head()
# Out:
#          Date Country  Population  Total Tests  Total Cases  Total Deaths  \
# 0  2020-04-18     USA   330774664    3722145.0     738792.0       39014.0
# 1  2020-04-18  Russia   145927292    1831892.0      36793.0         313.0
# 2  2020-04-18   Spain    46752703     930230.0     194416.0       20043.0
# 3  2020-04-18  Brazil   212380932      62985.0      36722.0        2361.0
# 4  2020-04-18      UK    67844241     460437.0     114217.0       15464.0
#
#    Total Recovered  Serious or Critical  Active Cases
# 0          68269.0              13551.0      631509.0
# 1           3057.0                  8.0       33423.0
# 2          74797.0               7371.0       99576.0
# 3          14026.0               6634.0       20335.0
# 4              NaN               1559.0       98409.0

# %% [markdown]
# We will replace the null values with mean of there respective columns as below

# %%
ds['Total Tests'].fillna(ds['Total Tests'].mean(), inplace = True)
ds['Total Cases'].fillna(ds['Total Cases'].mean(), inplace = True)
ds['Total Deaths'].fillna(ds['Total Deaths'].mean(), inplace = True)
ds['Total Recovered'].fillna(ds['Total Recovered'].mean(), inplace = True)
ds['Serious or Critical'].fillna(ds['Serious or Critical'].mean(), inplace = True)
ds['Active Cases'].fillna(ds['Active Cases'].mean(), inplace = True)

# %%
#We cannot process Date directly hence we will Split Date,Month and year in seperate columns
ds['year']=pd.DatetimeIndex(ds['Date']).year
ds['month']=pd.DatetimeIndex(ds['Date']).month
ds['day']=pd.DatetimeIndex(ds['Date']).day

# %%
#we need to remove the date columns after seperating Year,month and day
ds.drop(['Date'],inplace=True,axis=1)

# %%
ds
# Out:
#                      Country  Population   Total Tests  Total Cases  \
# 0                        USA   330774664  3.722145e+06     738792.0
# 1                     Russia   145927292  1.831892e+06      36793.0
# 2                      Spain    46752703  9.302300e+05     194416.0
# 3                     Brazil   212380932  6.298500e+04      36722.0
# 4                         UK    67844241  4.604370e+05     114217.0
# 5                      Italy    60471924  1.305833e+06     175925.0
# 6                     France    65256826  4.636620e+05     151793.0
# 7                    Germany    83752855  1.728357e+06     143724.0
# 8                     Turkey    84230075  5.989330e+05      82329.0
# 9                       Iran    83862642  3.301370e+05      80868.0
# 10                     India  1378381772  3.351230e+05      16365.0
# 11                      Peru    32915899  1.358950e+05      14420.0
# 12                     China  1439323776  2.167252e+05      82719.0
# ...

# %%
#Checking correlation using the heatmap
corr=ds.corr()
plt.figure(figsize=(16,5))
sn.heatmap(corr,annot=True,linewidths=.8)
plt.show()

# %% [markdown]
# It is observed that Active cases have highest correlation followed by total cases,Total deaths and seriour or critical columns.
# Month and day column are least correlated.

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6603 entries, 0 to 6602
# Data columns (total 11 columns):
# Country                6603 non-null object
# Population             6603 non-null int64
# Total Tests            6603 non-null float64
# Total Cases            6603 non-null float64
# Total Deaths           6603 non-null float64
# Total Recovered        6603 non-null float64
# Serious or Critical    6603 non-null float64
# Active Cases           6603 non-null float64
# year                   6603 non-null int64
# month                  6603 non-null int64
# day                    6603 non-null int64
# dtypes: float64(6), int64(4), object(1)
# memory usage: 567.5+ KB

# %%
#We will check for outliers using boxplot

# %%
sn.boxplot(data=ds["Population"])
plt.show()

# %%
sn.boxplot(data=ds["Total Tests"])
plt.show()

# %%
sn.boxplot(data=ds["Total Cases"])
plt.show()

# %%
sn.boxplot(data=ds["Total Recovered"])
plt.show()

# %%
sn.boxplot(data=ds["Serious or Critical"])
plt.show()

# %%
sn.boxplot(data=ds["Active Cases"])
plt.show()

# %%
sn.boxplot(data=ds["Active Cases"])
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
ds.Country=le.fit_transform(ds.Country)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6603 entries, 0 to 6602
# Data columns (total 11 columns):
# Country                6603 non-null int32
# Population             6603 non-null int64
# Total Tests            6603 non-null float64
# Total Cases            6603 non-null float64
# Total Deaths           6603 non-null float64
# Total Recovered        6603 non-null float64
# Serious or Critical    6603 non-null float64
# Active Cases           6603 non-null float64
# year                   6603 non-null int64
# month                  6603 non-null int64
# day                    6603 non-null int64
# dtypes: float64(6), int32(1), int64(4)
# memory usage: 541.7 KB

# %% [markdown]
# ds_n=ds
# from scipy import stats
# import numpy as np
# z = np.abs(stats.zscore(ds_n))
# print(z)
#
# threshold = 3
# print(np.where(z > 3))
#
# ds_n = ds_n[(z < 3).all(axis=1)]
#
# ds_n.shape
#
# Zscore is removing to many rows hence not using the zscore.

# %%
#creating target variable and seperating data into X and Y
x=ds.drop("Total Deaths",axis=1)
y=ds['Total Deaths']

#Spliting the data
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25)

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score

best_rstate=0
accu=0

for i in range(20,300):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=i)
    mod=LinearRegression()
    mod.fit(x_train,y_train)
    y_pred=mod.predict(x_test)
    tempaccu=r2_score(y_test,y_pred)
    if tempaccu>accu:
        accu=tempaccu
        best_rstate=i

        
print(f"best accuracy {accu*100} found on randome_state {best_rstate}")
# Out:
# best accuracy 95.10566486133084 found on randome_state 171

# %%
#Random Forest Regressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor
rd=RandomForestRegressor()
rd.fit(x_train,y_train)
y_pred=rd.predict(x_test)
r2score=r2_score(y_test,y_pred)
print(f"Accuracu is {r2score*100}")
# Out:
# C:\Users\ajay\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Accuracu is 98.65057350184188

# %%
#KNeighborsRegressor
from sklearn.neighbors import KNeighborsRegressor
model=KNeighborsRegressor(n_neighbors=3,p=2)
model.fit(x_train,y_train)

y_pred=model.predict(x_test)
score=r2_score(y_test,y_pred)
print(f"Accuracu is {score*100}")
# Out:
# Accuracu is 99.77829955878164

# %%
#We will use KNeighbors Regressor for hyper tuning as we are best result with it.

# %%
#We will try to improve performance of our best model using GridSearchCV
from sklearn.model_selection import GridSearchCV 
parameter = {'leaf_size':[1,3,5,7,9,11,13,15],
            'n_neighbors':[2,4,6,8,10,12,14],
             'p':[1,2]
            }

grid = GridSearchCV(model, parameter, refit = True, verbose = 3) 

grid.fit(x_train, y_train)

y_pred=grid.predict(x_test)
score=r2_score(y_test,y_pred)
print(f"Accuracu is {score*100}")
# Out:
# C:\Users\ajay\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# Fitting 3 folds for each of 112 candidates, totalling 336 fits
# [CV] leaf_size=1, n_neighbors=2, p=1 .................................
# [CV] ..... leaf_size=1, n_neighbors=2, p=1, score=0.993, total=   0.0s
# [CV] leaf_size=1, n_neighbors=2, p=1 .................................
# [CV] ..... leaf_size=1, n_neighbors=2, p=1, score=0.996, total=   0.0s
# [CV] leaf_size=1, n_neighbors=2, p=1 .................................
# ...

# %%
#We are using KNeighborsRegressor for hyper tunning parameter.
#After performing hyper tuning we got accuracy of 99.81%

# %%
#creating Pickle file
import pickle
filename = 'covid19.pkl'
pickle.dump(grid,open(filename, 'wb'))
